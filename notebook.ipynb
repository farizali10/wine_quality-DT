# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score,roc_curve
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv("D:\Data-Science-D-drive\Practical Implementation ML Algos\winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#ProfileReport(df)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
set(df.quality)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
x = df.drop(columns="quality")

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y  = df[["quality"]]

# %%
y.head()
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
x_train , x_test, y_train,y_test = train_test_split(x,y,test_size = .25,random_state = 30)

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_model.predict(x_test)
# Out:
# array([6, 3, 6, 6, 6, 5, 6, 6, 5, 3, 7, 6, 6, 5, 7, 4, 5, 5, 7, 6, 5, 7,
#        5, 5, 5, 5, 7, 6, 5, 5, 5, 6, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 7, 5,
#        5, 6, 6, 6, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 7, 5, 7, 5,
#        5, 6, 5, 7, 6, 5, 5, 5, 6, 6, 7, 5, 6, 5, 6, 7, 5, 6, 5, 6, 5, 5,
#        5, 6, 5, 5, 6, 4, 6, 6, 4, 6, 5, 4, 5, 5, 5, 7, 6, 5, 6, 5, 6, 5,
#        5, 5, 5, 7, 7, 6, 6, 6, 5, 6, 6, 7, 7, 6, 7, 5, 6, 5, 6, 6, 6, 5,
#        6, 5, 5, 6, 5, 3, 7, 7, 5, 5, 6, 6, 5, 5, 5, 4, 6, 7, 5, 5, 5, 6,
#        5, 6, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6,
#        5, 5, 6, 6, 5, 6, 7, 5, 6, 5, 6, 6, 4, 7, 5, 5, 5, 7, 6, 5, 7, 6,
#        5, 6, 7, 5, 5, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 5, 6, 5, 6, 5, 5, 6,
#        6, 6, 7, 6, 5, 6, 5, 6, 7, 5, 5, 6, 7, 7, 5, 5, 5, 7, 6, 6, 5, 6,
#        6, 5, 7, 5, 6, 7, 6, 5, 4, 7, 5, 6, 6, 5, 6, 6, 5, 6, 6, 5, 6, 6,
#        5, 6, 6, 4, 6, 6, 5, 4, 6, 5, 5, 5, 6, 6, 5, 5, 5, 4, 5, 6, 5, 5,
#        6, 5, 6, 6, 5, 6, 5, 6, 5, 6, 5, 6, 7, 6, 5, 6, 6, 5, 6, 5, 6, 5,
#        6, 6, 6, 5, 6, 6, 6, 6, 5, 6, 5, 5, 6, 6, 6, 4, 6, 5, 6, 5, 6, 5,
#        6, 5, 6, 5, 5, 4, 6, 5, 5, 5, 5, 7, 5, 6, 7, 4, 5, 6, 5, 6, 6, 6,
#        5, 5, 6, 5, 7, 5, 6, 6, 5, 7, 5, 5, 7, 5, 7, 7, 6, 6, 5, 5, 5, 6,
#        6, 6, 6, 5, 6, 5, 5, 6, 5, 6, 4, 6, 6, 5, 5, 6, 7, 6, 5, 6, 6, 5,
#        6, 6, 6, 6], dtype=int64)

# %%
dt_model.score(x_test,y_test)*100
# Out:
# 62.0

# %%
dt_ent = DecisionTreeClassifier(criterion='entropy')

# %%
dt_ent.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_ent.score(x_test,y_test)*100
# Out:
# 62.0

# %% [markdown]
# Genrating Meta File of the Model

# %%
outfile = dot_for_dt_ent = open("dt_ent.dot","w")
tree.export_graphviz(dt_ent,out_file=outfile, feature_names=x.columns)

# %%
dir()
# Out:
# ['DecisionTreeClassifier',
#  'GridSearchCV',
#  'In',
#  'Out',
#  'ProfileReport',
#  '_',
#  '_11',
#  '_14',
#  '_15',
#  '_16',
#  '_18',
#  '_19',
#  '_21',
#  '_23',
#  '_29',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_36',
#  '_4',
#  '_40',
#  '_42',
#  '_43',
#  '_46',
#  '_47',
#  '_50',
#  '_51',
#  '_52',
#  '_55',
#  '_57',
#  '_58',
#  '_6',
#  '_60',
#  '_62',
#  '_65',
#  '_66',
#  '_67',
#  '_69',
#  '_7',
#  '_70',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
#  '_i64',
#  '_i65',
#  '_i66',
#  '_i67',
#  '_i68',
#  '_i69',
#  '_i7',
#  '_i70',
#  '_i71',
#  '_i72',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'accuracy_score',
#  'ax',
#  'ccp',
#  'ccp_alpha',
#  'confusion_matrix',
#  'df',
#  'df1',
#  'dot_for_dt_ent',
#  'dt_ent',
#  'dt_m',
#  'dt_model',
#  'dt_model1',
#  'dt_model2',
#  'exit',
#  'fig',
#  'get_ipython',
#  'np',
#  'open',
#  'outfile',
#  'path',
#  'pd',
#  'plt',
#  'quit',
#  'roc_auc_score',
#  'roc_curve',
#  'sklearn',
#  'test_scoreCPP',
#  'train_scoreCPP',
#  'train_test_split',
#  'tree',
#  'x',
#  'x1',
#  'x_test',
#  'x_train',
#  'y',
#  'y1',
#  'y_test',
#  'y_train']

# %%
# Visualizing tree:
import sklearn
import matplotlib.pyplot as plt
from sklearn import tree
# %matplotlib inline

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %%
#plt.figure(figsize=(20,20))
#tree.plot_tree(dt_model,filled=True)

# %%
df1 = df.head(30)

# %%
x1 = df1.drop(columns="quality")

# %%
y1 = df1.quality

# %%
dt_model1 = DecisionTreeClassifier()

# %%
dt_model1.fit(x1,y1)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True)
# Out:
# [Text(0.375, 0.9166666666666666, 'x[1] <= 0.355\ngini = 0.471\nsamples = 30\nvalue = [1, 21, 5, 3]'),
#  Text(0.16666666666666666, 0.75, 'x[6] <= 81.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1]'),
#  Text(0.08333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.25, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5833333333333334, 0.75, 'x[6] <= 22.0\ngini = 0.334\nsamples = 26\nvalue = [1, 21, 2, 2]'),
#  Text(0.4166666666666667, 0.5833333333333334, 'x[5] <= 8.5\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'x[5] <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.4166666666666667, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.75, 0.5833333333333334, 'x[10] <= 9.05\ngini = 0.169\nsamples = 22\nvalue = [1, 20, 1, 0]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'x[1] <= 0.415\ngini = 0.091\nsamples = 21\nvalue = [0, 20, 1, 0]'),
#  Text(0.75, 0.25, 'x[2] <= 0.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.9166666666666666, 0.25, 'gini = 0.0\nsamples = 18\nvalue = [0, 18, 0, 0]')]

# %% [markdown]
# ## Inferences:
# - Samples in the box1 mean no of datapoints we have considered.
# - Values in box1 mean that we had 4 classes i.e. 4,5,6,7 in quality column (output column) so values = [1,21,5,3] means we have:
#     - 1 value of class 4
#     - 21 values of class 5
#     - 5 values of class 6
#     - 3 values of class 7
#
#
#     <br>Total of all values will result in total sample values i.e. 1 + 21 + 5 + 3 = 30
#
# - x[1] here means the column which is the parent node i.e. 2nd column of x dataframe which shows it has the lowest gini impurity
#
#     - Based on x[2] = 0.335 (threshold) of x[2] column values if greater than it will got right side else left
# - 26 samples in right side split shows 26 values greater than x[2]'s 0.335.
# - Now in left hand node the same thing is repeated started from again calculating gini.

# %%
# Plot with column and class names

plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True,class_names = [str(i)for i in set(y1)], feature_names = x1.columns)
# Out:
# [Text(0.375, 0.9166666666666666, 'volatile acidity <= 0.355\ngini = 0.471\nsamples = 30\nvalue = [1, 21, 5, 3]\nclass = 5'),
#  Text(0.16666666666666666, 0.75, 'total sulfur dioxide <= 81.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1]\nclass = 6'),
#  Text(0.08333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = 6'),
#  Text(0.25, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = 7'),
#  Text(0.5833333333333334, 0.75, 'total sulfur dioxide <= 22.0\ngini = 0.334\nsamples = 26\nvalue = [1, 21, 2, 2]\nclass = 5'),
#  Text(0.4166666666666667, 0.5833333333333334, 'free sulfur dioxide <= 8.5\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2]\nclass = 7'),
#  Text(0.3333333333333333, 0.4166666666666667, 'free sulfur dioxide <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = 5'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = 5'),
#  Text(0.4166666666666667, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = 6'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = 7'),
#  Text(0.75, 0.5833333333333334, 'alcohol <= 9.05\ngini = 0.169\nsamples = 22\nvalue = [1, 20, 1, 0]\nclass = 5'),
#  Text(0.6666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = 4'),
#  Text(0.8333333333333334, 0.4166666666666667, 'volatile acidity <= 0.415\ngini = 0.091\nsamples = 21\nvalue = [0, 20, 1, 0]\nclass = 5'),
#  Text(0.75, 0.25, 'citric acid <= 0.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = 5'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = 6'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = 5'),
#  Text(0.9166666666666666, 0.25, 'gini = 0.0\nsamples = 18\nvalue = [0, 18, 0, 0]\nclass = 5')]

# %% [markdown]
# - Performing Post Prunning on level 3 where there are 20 records for class 5 and 1 record for class 6.
#     - Removing level 3 to control complexity of the tree

# %%
# Checking train and test accuracy
dt_model1.predict(x1)
# Out:
# array([5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5,
#        5, 5, 6, 5, 5, 5, 5, 6], dtype=int64)

# %%
dt_model1.score(x1,y1)
# Out:
# 1.0

# %%
dt_model1.score(x_test,y_test)
# Out:
# 0.49

# %% [markdown]
# Here the model is overfitted as we are getting higher accuracy and on random sample as input its giving lower accuracy.
#
# - Here lower accuracy isnt a great issue as compared to overfitting so we would resolve overfitting here.

# %% [markdown]
# # FineTuning CPP:
# by default cpp = 0 as it would create the most separations in a tree i can so we would try to control complexity of the model by choosing best CPP.

# %%
path = dt_model1.cost_complexity_pruning_path(x1,y1)

# %%
path
# Out:
# {'ccp_alphas': array([0.        , 0.03174603, 0.03333333, 0.05      , 0.05      ,
#         0.06075036, 0.08216783, 0.13136752]),
#  'impurities': array([0.        , 0.06349206, 0.0968254 , 0.1468254 , 0.1968254 ,
#         0.25757576, 0.33974359, 0.47111111])}

# %%
ccp_alpha = path.ccp_alphas

# %%
# Passsing different ccp alphas
dt_model2 = []
for ccp in ccp_alpha:
    dt_m = DecisionTreeClassifier(ccp_alpha=ccp)
    dt_m.fit(x1,y1)
    dt_model2.append(dt_m)

# %%
dt_model2
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.03174603174603176),
#  DecisionTreeClassifier(ccp_alpha=0.03333333333333333),
#  DecisionTreeClassifier(ccp_alpha=0.049999999999999996),
#  DecisionTreeClassifier(ccp_alpha=0.05),
#  DecisionTreeClassifier(ccp_alpha=0.06075036075036072),
#  DecisionTreeClassifier(ccp_alpha=0.08216783216783222),
#  DecisionTreeClassifier(ccp_alpha=0.1313675213675214)]

# %% [markdown]
# First one has ccp_alpha = 0
# <br>
#
# In total we have built 8 models so far

# %%
"""train_score = dt_model1.score(x1,y1) fo
test_score = dt_model1.score()"""
# Out:
# 'train_score = dt_model1.score(x1,y1) fo\ntest_score = dt_model1.score()'

# %%
train_scoreCPP = [i.score(x1,y1) for i in dt_model2]

# %%
test_scoreCPP = [i.score(x_test,y_test) for i in dt_model2]

# %%
test_scoreCPP
# Out:
# [0.4525, 0.4175, 0.45, 0.445, 0.44, 0.445, 0.4625, 0.4225]

# %%
train_scoreCPP
# Out:
# [1.0,
#  0.9666666666666667,
#  0.9333333333333333,
#  0.9,
#  0.8666666666666667,
#  0.8333333333333334,
#  0.8,
#  0.7]

# %%
fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alpha, train_scoreCPP, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alpha, test_scoreCPP, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# Here the accuracy is low but we are still doing some progress in terms of reducing overfitting but the overfitting is due to the fact that our training dataset is very small and testing dataset is large so our model wasnt even able to learn patterns of test data that are unavailable completely in training data.

# %% [markdown]
# # Increasing the training size:

# %%
df1 = df.head(500)

# %%
x1 = df1.drop(columns="quality")

# %%
y1 = df1.quality

# %%
dt_model1 = DecisionTreeClassifier()

# %%
dt_model1.fit(x1,y1)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True)
# Out:
# [Text(0.4462519341290893, 0.9705882352941176, 'x[10] <= 9.85\ngini = 0.624\nsamples = 500\nvalue = [1, 16, 239, 184, 52, 8]'),
#  Text(0.27928824049513706, 0.9117647058823529, 'x[6] <= 62.5\ngini = 0.504\nsamples = 259\nvalue = [1, 12, 167, 72, 6, 1]'),
#  Text(0.17484526967285588, 0.8529411764705882, 'x[2] <= 0.415\ngini = 0.576\nsamples = 169\nvalue = [1, 9, 91, 61, 6, 1]'),
#  Text(0.07736516357206012, 0.7941176470588235, 'x[10] <= 9.05\ngini = 0.525\nsamples = 131\nvalue = [0, 8, 81, 39, 3, 0]'),
#  Text(0.021220159151193633, 0.7352941176470589, 'x[9] <= 0.54\ngini = 0.403\nsamples = 12\nvalue = [0, 2, 1, 9, 0, 0]'),
#  Text(0.014146772767462422, 0.6764705882352942, 'x[0] <= 7.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.007073386383731211, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.021220159151193633, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.028293545534924844, 0.6764705882352942, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.13351016799292661, 0.7352941176470589, 'x[7] <= 0.999\ngini = 0.481\nsamples = 119\nvalue = [0, 6, 80, 30, 3, 0]'),
#  Text(0.08311229000884174, 0.6764705882352942, 'x[8] <= 3.285\ngini = 0.443\nsamples = 108\nvalue = [0, 5, 77, 23, 3, 0]'),
#  Text(0.03536693191865606, 0.6176470588235294, 'x[9] <= 0.53\ngini = 0.216\nsamples = 34\nvalue = [0, 2, 30, 1, 1, 0]'),
#  Text(0.028293545534924844, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.042440318302387266, 0.5588235294117647, 'x[10] <= 9.65\ngini = 0.171\nsamples = 33\nvalue = [0, 1, 30, 1, 1, 0]'),
#  Text(0.028293545534924844, 0.5, 'x[3] <= 1.4\ngini = 0.074\nsamples = 26\nvalue = [0, 1, 25, 0, 0, 0]'),
#  Text(0.021220159151193633, 0.4411764705882353, 'x[6] <= 25.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.014146772767462422, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.028293545534924844, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.03536693191865606, 0.4411764705882353, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0, 0, 0]'),
#  Text(0.05658709106984969, 0.5, 'x[9] <= 0.705\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 5, 1, 1, 0]'),
#  Text(0.04951370468611848, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.0636604774535809, 0.4411764705882353, 'x[5] <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.05658709106984969, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07073386383731212, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.13085764809902742, 0.6176470588235294, 'x[1] <= 0.665\ngini = 0.506\nsamples = 74\nvalue = [0, 3, 47, 22, 2, 0]'),
#  Text(0.11317418213969938, 0.5588235294117647, 'x[7] <= 0.996\ngini = 0.53\nsamples = 52\nvalue = [0, 0, 28, 22, 2, 0]'),
#  Text(0.09902740937223696, 0.5, 'x[2] <= 0.06\ngini = 0.291\nsamples = 17\nvalue = [0, 0, 14, 3, 0, 0]'),
#  Text(0.09195402298850575, 0.4411764705882353, 'x[0] <= 6.7\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.08488063660477453, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.09902740937223696, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.10610079575596817, 0.4411764705882353, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.1273209549071618, 0.5, 'x[4] <= 0.087\ngini = 0.542\nsamples = 35\nvalue = [0, 0, 14, 19, 2, 0]'),
#  Text(0.12024756852343059, 0.4411764705882353, 'x[9] <= 0.635\ngini = 0.561\nsamples = 29\nvalue = [0, 0, 14, 13, 2, 0]'),
#  Text(0.11317418213969938, 0.38235294117647056, 'x[1] <= 0.47\ngini = 0.541\nsamples = 22\nvalue = [0, 0, 7, 13, 2, 0]'),
#  Text(0.10610079575596817, 0.3235294117647059, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.12024756852343059, 0.3235294117647059, 'x[3] <= 2.1\ngini = 0.604\nsamples = 15\nvalue = [0, 0, 7, 6, 2, 0]'),
#  Text(0.11317418213969938, 0.2647058823529412, 'x[3] <= 1.85\ngini = 0.595\nsamples = 11\nvalue = [0, 0, 3, 6, 2, 0]'),
#  Text(0.09902740937223696, 0.20588235294117646, 'x[5] <= 10.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.09195402298850575, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.10610079575596817, 0.14705882352941177, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.1273209549071618, 0.20588235294117646, 'x[1] <= 0.6\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(0.12024756852343059, 0.14705882352941177, 'x[9] <= 0.535\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.11317418213969938, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1273209549071618, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.134394341290893, 0.14705882352941177, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.1273209549071618, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.1273209549071618, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.134394341290893, 0.4411764705882353, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.14854111405835543, 0.5588235294117647, 'x[9] <= 0.485\ngini = 0.236\nsamples = 22\nvalue = [0, 3, 19, 0, 0, 0]'),
#  Text(0.14146772767462423, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.15561450044208666, 0.5, 'x[2] <= 0.24\ngini = 0.095\nsamples = 20\nvalue = [0, 1, 19, 0, 0, 0]'),
#  Text(0.14854111405835543, 0.4411764705882353, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.16268788682581786, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1839080459770115, 0.6764705882352942, 'x[10] <= 9.65\ngini = 0.512\nsamples = 11\nvalue = [0, 1, 3, 7, 0, 0]'),
#  Text(0.16976127320954906, 0.6176470588235294, 'x[1] <= 0.385\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.16268788682581786, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1768346595932803, 0.5588235294117647, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.19805481874447392, 0.6176470588235294, 'x[9] <= 0.76\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.1909814323607427, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.20512820512820512, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2723253757736516, 0.7941176470588235, 'x[2] <= 0.565\ngini = 0.587\nsamples = 38\nvalue = [1, 1, 10, 22, 3, 1]'),
#  Text(0.24049513704686118, 0.7352941176470589, 'x[0] <= 12.35\ngini = 0.438\nsamples = 26\nvalue = [0, 1, 3, 19, 3, 0]'),
#  Text(0.21927497789566755, 0.6764705882352942, 'x[3] <= 1.65\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 3, 18, 0, 0]'),
#  Text(0.21220159151193635, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22634836427939875, 0.6176470588235294, 'x[7] <= 1.0\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 2, 18, 0, 0]'),
#  Text(0.21927497789566755, 0.5588235294117647, 'x[9] <= 0.52\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 1, 18, 0, 0]'),
#  Text(0.21220159151193635, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22634836427939875, 0.5, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]'),
#  Text(0.23342175066312998, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.26171529619805484, 0.6764705882352942, 'x[9] <= 0.825\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 1, 3, 0]'),
#  Text(0.2546419098143236, 0.6176470588235294, 'x[5] <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.2475685234305924, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.26171529619805484, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.268788682581786, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.3041556145004421, 0.7352941176470589, 'x[8] <= 3.165\ngini = 0.583\nsamples = 12\nvalue = [1, 0, 7, 3, 0, 1]'),
#  Text(0.29000884173297964, 0.6764705882352942, 'x[1] <= 0.335\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 7, 1, 0, 1]'),
#  Text(0.28293545534924847, 0.6176470588235294, 'x[1] <= 0.29\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.27586206896551724, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29000884173297964, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.29708222811671087, 0.6176470588235294, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.3183023872679045, 0.6764705882352942, 'x[4] <= 0.081\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0, 0]'),
#  Text(0.3112290008841733, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.3253757736516357, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3837312113174182, 0.8529411764705882, 'x[4] <= 0.539\ngini = 0.271\nsamples = 90\nvalue = [0, 3, 76, 11, 0, 0]'),
#  Text(0.376657824933687, 0.7941176470588235, 'x[8] <= 3.335\ngini = 0.255\nsamples = 89\nvalue = [0, 2, 76, 11, 0, 0]'),
#  Text(0.34659593280282935, 0.7352941176470589, 'x[4] <= 0.067\ngini = 0.176\nsamples = 73\nvalue = [0, 1, 66, 6, 0, 0]'),
#  Text(0.3395225464190981, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3536693191865606, 0.6764705882352942, 'x[3] <= 1.55\ngini = 0.155\nsamples = 72\nvalue = [0, 1, 66, 5, 0, 0]'),
#  Text(0.3395225464190981, 0.6176470588235294, 'x[6] <= 107.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.33244916003536695, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.34659593280282935, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.367816091954023, 0.6176470588235294, 'x[7] <= 0.996\ngini = 0.133\nsamples = 70\nvalue = [0, 0, 65, 5, 0, 0]'),
#  Text(0.36074270557029176, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3748894783377542, 0.5588235294117647, 'x[9] <= 1.6\ngini = 0.109\nsamples = 69\nvalue = [0, 0, 65, 4, 0, 0]'),
#  Text(0.36074270557029176, 0.5, 'x[8] <= 3.265\ngini = 0.086\nsamples = 67\nvalue = [0, 0, 64, 3, 0, 0]'),
#  Text(0.3536693191865606, 0.4411764705882353, 'gini = 0.0\nsamples = 46\nvalue = [0, 0, 46, 0, 0, 0]'),
#  Text(0.367816091954023, 0.4411764705882353, 'x[5] <= 33.5\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 18, 3, 0, 0]'),
#  Text(0.36074270557029176, 0.38235294117647056, 'x[1] <= 0.545\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]'),
#  Text(0.3536693191865606, 0.3235294117647059, 'x[5] <= 21.5\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.34659593280282935, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.36074270557029176, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.367816091954023, 0.3235294117647059, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.3748894783377542, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3890362511052166, 0.5, 'x[8] <= 2.985\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3819628647214854, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39610963748894784, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.40671971706454463, 0.7352941176470589, 'x[2] <= 0.145\ngini = 0.508\nsamples = 16\nvalue = [0, 1, 10, 5, 0, 0]'),
#  Text(0.3890362511052166, 0.6764705882352942, 'x[9] <= 0.57\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.3819628647214854, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.39610963748894784, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.4244031830238727, 0.6764705882352942, 'x[0] <= 7.9\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3, 0, 0]'),
#  Text(0.41025641025641024, 0.6176470588235294, 'x[8] <= 3.565\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]'),
#  Text(0.40318302387267907, 0.5588235294117647, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.41732979664014147, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4385499557913351, 0.6176470588235294, 'x[1] <= 0.44\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.43147656940760387, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.44562334217506633, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39080459770114945, 0.7941176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6132156277630415, 0.9117647058823529, 'x[9] <= 0.545\ngini = 0.657\nsamples = 241\nvalue = [0, 4, 72, 112, 46, 7]'),
#  Text(0.46684350132625996, 0.8529411764705882, 'x[4] <= 0.08\ngini = 0.408\nsamples = 32\nvalue = [0, 2, 24, 5, 1, 0]'),
#  Text(0.45977011494252873, 0.7941176470588235, 'x[7] <= 0.995\ngini = 0.675\nsamples = 13\nvalue = [0, 2, 5, 5, 1, 0]'),
#  Text(0.44562334217506633, 0.7352941176470589, 'x[1] <= 0.835\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1, 0]'),
#  Text(0.4385499557913351, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4526967285587975, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.4739168877099912, 0.7352941176470589, 'x[1] <= 0.475\ngini = 0.5\nsamples = 10\nvalue = [0, 0, 5, 5, 0, 0]'),
#  Text(0.46684350132625996, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.48099027409372236, 0.6764705882352942, 'x[0] <= 7.05\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.4739168877099912, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4880636604774536, 0.6176470588235294, 'x[7] <= 0.998\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.48099027409372236, 0.5588235294117647, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.4951370468611848, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4739168877099912, 0.7941176470588235, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.7595877541998232, 0.8529411764705882, 'x[9] <= 0.705\ngini = 0.638\nsamples = 209\nvalue = [0, 2, 48, 107, 45, 7]'),
#  Text(0.6195291777188329, 0.7941176470588235, 'x[2] <= 0.745\ngini = 0.53\nsamples = 100\nvalue = [0, 2, 23, 64, 8, 3]'),
#  Text(0.6124557913351016, 0.7352941176470589, 'x[8] <= 3.485\ngini = 0.513\nsamples = 98\nvalue = [0, 2, 23, 64, 6, 3]'),
#  Text(0.5432139699381079, 0.6764705882352942, 'x[8] <= 3.055\ngini = 0.45\nsamples = 83\nvalue = [0, 1, 17, 59, 3, 3]'),
#  Text(0.5163572060123784, 0.6176470588235294, 'x[6] <= 24.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.5092838196286472, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5234305923961097, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5700707338638373, 0.6176470588235294, 'x[5] <= 5.5\ngini = 0.427\nsamples = 79\nvalue = [0, 1, 14, 58, 3, 3]'),
#  Text(0.537577365163572, 0.5588235294117647, 'x[7] <= 0.998\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 3, 3, 0, 2]'),
#  Text(0.5305039787798409, 0.5, 'x[8] <= 3.18\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 0, 2]'),
#  Text(0.5234305923961097, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.537577365163572, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5446507515473032, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.6025641025641025, 0.5588235294117647, 'x[8] <= 3.385\ngini = 0.374\nsamples = 71\nvalue = [0, 1, 11, 55, 3, 1]'),
#  Text(0.5587975243147657, 0.5, 'x[3] <= 4.65\ngini = 0.324\nsamples = 54\nvalue = [0, 1, 5, 44, 3, 1]'),
#  Text(0.5517241379310345, 0.4411764705882353, 'x[2] <= 0.035\ngini = 0.298\nsamples = 53\nvalue = [0, 1, 5, 44, 3, 0]'),
#  Text(0.5446507515473032, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5587975243147657, 0.38235294117647056, 'x[7] <= 1.0\ngini = 0.274\nsamples = 52\nvalue = [0, 1, 4, 44, 3, 0]'),
#  Text(0.5278514588859416, 0.3235294117647059, 'x[2] <= 0.305\ngini = 0.228\nsamples = 48\nvalue = [0, 1, 3, 42, 2, 0]'),
#  Text(0.5048629531388152, 0.2647058823529412, 'x[8] <= 3.155\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 1, 23, 0, 0]'),
#  Text(0.497789566755084, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5119363395225465, 0.20588235294117646, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0, 0]'),
#  Text(0.5508399646330681, 0.2647058823529412, 'x[10] <= 10.45\ngini = 0.358\nsamples = 24\nvalue = [0, 1, 2, 19, 2, 0]'),
#  Text(0.5260831122900088, 0.20588235294117646, 'x[5] <= 11.0\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 1, 1, 0]'),
#  Text(0.5190097259062776, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.53315649867374, 0.14705882352941177, 'x[2] <= 0.315\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 1, 0]'),
#  Text(0.5260831122900088, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5402298850574713, 0.08823529411764706, 'x[2] <= 0.34\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.53315649867374, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5473032714412025, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5755968169761273, 0.20588235294117646, 'x[1] <= 0.3\ngini = 0.185\nsamples = 20\nvalue = [0, 0, 1, 18, 1, 0]'),
#  Text(0.5614500442086648, 0.14705882352941177, 'x[1] <= 0.235\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.5543766578249337, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5685234305923961, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5897435897435898, 0.14705882352941177, 'x[7] <= 0.996\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 0, 17, 1, 0]'),
#  Text(0.5826702033598585, 0.08823529411764706, 'x[4] <= 0.065\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.5755968169761273, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5897435897435898, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.596816976127321, 0.08823529411764706, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.5897435897435898, 0.3235294117647059, 'x[4] <= 0.091\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.5826702033598585, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.596816976127321, 0.2647058823529412, 'x[4] <= 0.098\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.5897435897435898, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6038903625110522, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5658709106984969, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6463306808134395, 0.5, 'x[1] <= 0.695\ngini = 0.457\nsamples = 17\nvalue = [0, 0, 6, 11, 0, 0]'),
#  Text(0.6392572944297082, 0.4411764705882353, 'x[6] <= 53.5\ngini = 0.391\nsamples = 15\nvalue = [0, 0, 4, 11, 0, 0]'),
#  Text(0.6251105216622458, 0.38235294117647056, 'x[8] <= 3.415\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.6180371352785146, 0.3235294117647059, 'x[7] <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.6109637488947833, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6251105216622458, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.632183908045977, 0.3235294117647059, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.6534040671971706, 0.38235294117647056, 'x[5] <= 27.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.6463306808134395, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.6604774535809018, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6534040671971706, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6816976127320955, 0.6764705882352942, 'x[9] <= 0.625\ngini = 0.684\nsamples = 15\nvalue = [0, 1, 6, 5, 3, 0]'),
#  Text(0.6746242263483643, 0.6176470588235294, 'x[5] <= 18.0\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 0, 5, 3, 0]'),
#  Text(0.667550839964633, 0.5588235294117647, 'x[4] <= 0.056\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.6604774535809018, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6746242263483643, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.6816976127320955, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.6887709991158267, 0.6176470588235294, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.6266025641025641, 0.7352941176470589, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8996463306808135, 0.7941176470588235, 'x[9] <= 0.925\ngini = 0.675\nsamples = 109\nvalue = [0, 0, 25, 43, 37, 4]'),
#  Text(0.8275862068965517, 0.7352941176470589, 'x[6] <= 62.0\ngini = 0.687\nsamples = 88\nvalue = [0, 0, 24, 26, 34, 4]'),
#  Text(0.7541998231653404, 0.6764705882352942, 'x[10] <= 10.45\ngini = 0.632\nsamples = 62\nvalue = [0, 0, 8, 21, 30, 3]'),
#  Text(0.7099911582670203, 0.6176470588235294, 'x[5] <= 10.5\ngini = 0.521\nsamples = 19\nvalue = [0, 0, 2, 12, 5, 0]'),
#  Text(0.695844385499558, 0.5588235294117647, 'x[8] <= 3.23\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 2, 5, 0]'),
#  Text(0.6887709991158267, 0.5, 'x[9] <= 0.86\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 0, 5, 0]'),
#  Text(0.6816976127320955, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.695844385499558, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7029177718832891, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7241379310344828, 0.5588235294117647, 'x[1] <= 0.632\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.7170645446507515, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.731211317418214, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7984084880636605, 0.6176470588235294, 'x[8] <= 3.33\ngini = 0.594\nsamples = 43\nvalue = [0, 0, 6, 9, 25, 3]'),
#  Text(0.7736516357206012, 0.5588235294117647, 'x[2] <= 0.615\ngini = 0.678\nsamples = 30\nvalue = [0, 0, 6, 9, 13, 2]'),
#  Text(0.7453580901856764, 0.5, 'x[1] <= 0.415\ngini = 0.711\nsamples = 22\nvalue = [0, 0, 6, 8, 6, 2]'),
#  Text(0.7099911582670203, 0.4411764705882353, 'x[6] <= 18.5\ngini = 0.678\nsamples = 11\nvalue = [0, 0, 3, 1, 5, 2]'),
#  Text(0.695844385499558, 0.38235294117647056, 'x[10] <= 11.15\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 0, 2]'),
#  Text(0.6887709991158267, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7029177718832891, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.7241379310344828, 0.38235294117647056, 'x[0] <= 11.25\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 1, 5, 0]'),
#  Text(0.7170645446507515, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.731211317418214, 0.3235294117647059, 'x[5] <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7241379310344828, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7382847038019452, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7807250221043325, 0.4411764705882353, 'x[3] <= 3.05\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 3, 7, 1, 0]'),
#  Text(0.76657824933687, 0.38235294117647056, 'x[0] <= 12.2\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]'),
#  Text(0.7595048629531388, 0.3235294117647059, 'x[6] <= 17.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.7524314765694076, 0.2647058823529412, 'x[3] <= 2.35\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7453580901856764, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7595048629531388, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.76657824933687, 0.2647058823529412, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7736516357206012, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7948717948717948, 0.38235294117647056, 'x[9] <= 0.835\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.7877984084880637, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.801945181255526, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.801945181255526, 0.5, 'x[6] <= 38.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.7948717948717948, 0.4411764705882353, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.8090185676392573, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8231653404067197, 0.5588235294117647, 'x[10] <= 12.65\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 0, 0, 12, 1]'),
#  Text(0.8160919540229885, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 11, 0]'),
#  Text(0.830238726790451, 0.5, 'x[1] <= 0.38\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.8231653404067197, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8373121131741822, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.900972590627763, 0.6764705882352942, 'x[10] <= 11.35\ngini = 0.559\nsamples = 26\nvalue = [0, 0, 16, 5, 4, 1]'),
#  Text(0.865605658709107, 0.6176470588235294, 'x[1] <= 0.33\ngini = 0.29\nsamples = 18\nvalue = [0, 0, 15, 1, 2, 0]'),
#  Text(0.8514588859416445, 0.5588235294117647, 'x[8] <= 3.29\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.8443854995579133, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8585322723253758, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8797524314765695, 0.5588235294117647, 'x[7] <= 0.999\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(0.8726790450928382, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.8868258178603006, 0.5, 'x[5] <= 28.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8797524314765695, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8938992042440318, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9363395225464191, 0.6176470588235294, 'x[0] <= 9.1\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 1, 4, 2, 1]'),
#  Text(0.9221927497789567, 0.5588235294117647, 'x[4] <= 0.048\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 4, 1, 1]'),
#  Text(0.9151193633952255, 0.5, 'x[10] <= 12.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.9080459770114943, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9221927497789567, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9292661361626879, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.9504862953138815, 0.5588235294117647, 'x[0] <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9434129089301503, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9575596816976127, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9717064544650752, 0.7352941176470589, 'x[6] <= 18.5\ngini = 0.322\nsamples = 21\nvalue = [0, 0, 1, 17, 3, 0]'),
#  Text(0.9575596816976127, 0.6764705882352942, 'x[8] <= 3.11\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.9504862953138815, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.964633068081344, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.9858532272325375, 0.6764705882352942, 'x[4] <= 0.071\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 1, 16, 0, 0]'),
#  Text(0.9787798408488063, 0.6176470588235294, 'x[3] <= 2.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.9717064544650752, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9858532272325375, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9929266136162688, 0.6176470588235294, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]')]

# %% [markdown]
# ## Inferences:
# - Samples in the box1 mean no of datapoints we have considered.
# - Values in box1 mean that we had 4 classes i.e. 4,5,6,7 in quality column (output column) so values = [1,21,5,3] means we have:
#     - 1 value of class 4
#     - 21 values of class 5
#     - 5 values of class 6
#     - 3 values of class 7
#
#
#     <br>Total of all values will result in total sample values i.e. 1 + 21 + 5 + 3 = 30
#
# - x[1] here means the column which is the parent node i.e. 2nd column of x dataframe which shows it has the lowest gini impurity
#
#     - Based on x[2] = 0.335 (threshold) of x[2] column values if greater than it will got right side else left
# - 26 samples in right side split shows 26 values greater than x[2]'s 0.335.
# - Now in left hand node the same thing is repeated started from again calculating gini.

# %%
# Plot with column and class names

plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True,class_names = [str(i)for i in set(y1)], feature_names = x1.columns)
# Out:
# [Text(0.4462519341290893, 0.9705882352941176, 'alcohol <= 9.85\ngini = 0.624\nsamples = 500\nvalue = [1, 16, 239, 184, 52, 8]\nclass = 5'),
#  Text(0.27928824049513706, 0.9117647058823529, 'total sulfur dioxide <= 62.5\ngini = 0.504\nsamples = 259\nvalue = [1, 12, 167, 72, 6, 1]\nclass = 5'),
#  Text(0.17484526967285588, 0.8529411764705882, 'citric acid <= 0.415\ngini = 0.576\nsamples = 169\nvalue = [1, 9, 91, 61, 6, 1]\nclass = 5'),
#  Text(0.07736516357206012, 0.7941176470588235, 'alcohol <= 9.05\ngini = 0.525\nsamples = 131\nvalue = [0, 8, 81, 39, 3, 0]\nclass = 5'),
#  Text(0.021220159151193633, 0.7352941176470589, 'sulphates <= 0.54\ngini = 0.403\nsamples = 12\nvalue = [0, 2, 1, 9, 0, 0]\nclass = 6'),
#  Text(0.014146772767462422, 0.6764705882352942, 'fixed acidity <= 7.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.007073386383731211, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.021220159151193633, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.028293545534924844, 0.6764705882352942, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]\nclass = 6'),
#  Text(0.13351016799292661, 0.7352941176470589, 'density <= 0.999\ngini = 0.481\nsamples = 119\nvalue = [0, 6, 80, 30, 3, 0]\nclass = 5'),
#  Text(0.08311229000884174, 0.6764705882352942, 'pH <= 3.285\ngini = 0.443\nsamples = 108\nvalue = [0, 5, 77, 23, 3, 0]\nclass = 5'),
#  Text(0.03536693191865606, 0.6176470588235294, 'sulphates <= 0.53\ngini = 0.216\nsamples = 34\nvalue = [0, 2, 30, 1, 1, 0]\nclass = 5'),
#  Text(0.028293545534924844, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.042440318302387266, 0.5588235294117647, 'alcohol <= 9.65\ngini = 0.171\nsamples = 33\nvalue = [0, 1, 30, 1, 1, 0]\nclass = 5'),
#  Text(0.028293545534924844, 0.5, 'residual sugar <= 1.4\ngini = 0.074\nsamples = 26\nvalue = [0, 1, 25, 0, 0, 0]\nclass = 5'),
#  Text(0.021220159151193633, 0.4411764705882353, 'total sulfur dioxide <= 25.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.014146772767462422, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.028293545534924844, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.03536693191865606, 0.4411764705882353, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0, 0, 0]\nclass = 5'),
#  Text(0.05658709106984969, 0.5, 'sulphates <= 0.705\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 5, 1, 1, 0]\nclass = 5'),
#  Text(0.04951370468611848, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.0636604774535809, 0.4411764705882353, 'free sulfur dioxide <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.05658709106984969, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.07073386383731212, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.13085764809902742, 0.6176470588235294, 'volatile acidity <= 0.665\ngini = 0.506\nsamples = 74\nvalue = [0, 3, 47, 22, 2, 0]\nclass = 5'),
#  Text(0.11317418213969938, 0.5588235294117647, 'density <= 0.996\ngini = 0.53\nsamples = 52\nvalue = [0, 0, 28, 22, 2, 0]\nclass = 5'),
#  Text(0.09902740937223696, 0.5, 'citric acid <= 0.06\ngini = 0.291\nsamples = 17\nvalue = [0, 0, 14, 3, 0, 0]\nclass = 5'),
#  Text(0.09195402298850575, 0.4411764705882353, 'fixed acidity <= 6.7\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]\nclass = 6'),
#  Text(0.08488063660477453, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.09902740937223696, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.10610079575596817, 0.4411764705882353, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]\nclass = 5'),
#  Text(0.1273209549071618, 0.5, 'chlorides <= 0.087\ngini = 0.542\nsamples = 35\nvalue = [0, 0, 14, 19, 2, 0]\nclass = 6'),
#  Text(0.12024756852343059, 0.4411764705882353, 'sulphates <= 0.635\ngini = 0.561\nsamples = 29\nvalue = [0, 0, 14, 13, 2, 0]\nclass = 5'),
#  Text(0.11317418213969938, 0.38235294117647056, 'volatile acidity <= 0.47\ngini = 0.541\nsamples = 22\nvalue = [0, 0, 7, 13, 2, 0]\nclass = 6'),
#  Text(0.10610079575596817, 0.3235294117647059, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]\nclass = 6'),
#  Text(0.12024756852343059, 0.3235294117647059, 'residual sugar <= 2.1\ngini = 0.604\nsamples = 15\nvalue = [0, 0, 7, 6, 2, 0]\nclass = 5'),
#  Text(0.11317418213969938, 0.2647058823529412, 'residual sugar <= 1.85\ngini = 0.595\nsamples = 11\nvalue = [0, 0, 3, 6, 2, 0]\nclass = 6'),
#  Text(0.09902740937223696, 0.20588235294117646, 'free sulfur dioxide <= 10.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.09195402298850575, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.10610079575596817, 0.14705882352941177, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.1273209549071618, 0.20588235294117646, 'volatile acidity <= 0.6\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]\nclass = 6'),
#  Text(0.12024756852343059, 0.14705882352941177, 'sulphates <= 0.535\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]\nclass = 7'),
#  Text(0.11317418213969938, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.1273209549071618, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.134394341290893, 0.14705882352941177, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.1273209549071618, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.1273209549071618, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]\nclass = 5'),
#  Text(0.134394341290893, 0.4411764705882353, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(0.14854111405835543, 0.5588235294117647, 'sulphates <= 0.485\ngini = 0.236\nsamples = 22\nvalue = [0, 3, 19, 0, 0, 0]\nclass = 5'),
#  Text(0.14146772767462423, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.15561450044208666, 0.5, 'citric acid <= 0.24\ngini = 0.095\nsamples = 20\nvalue = [0, 1, 19, 0, 0, 0]\nclass = 5'),
#  Text(0.14854111405835543, 0.4411764705882353, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]\nclass = 5'),
#  Text(0.16268788682581786, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.1839080459770115, 0.6764705882352942, 'alcohol <= 9.65\ngini = 0.512\nsamples = 11\nvalue = [0, 1, 3, 7, 0, 0]\nclass = 6'),
#  Text(0.16976127320954906, 0.6176470588235294, 'volatile acidity <= 0.385\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]\nclass = 6'),
#  Text(0.16268788682581786, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.1768346595932803, 0.5588235294117647, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]\nclass = 6'),
#  Text(0.19805481874447392, 0.6176470588235294, 'sulphates <= 0.76\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.1909814323607427, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.20512820512820512, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.2723253757736516, 0.7941176470588235, 'citric acid <= 0.565\ngini = 0.587\nsamples = 38\nvalue = [1, 1, 10, 22, 3, 1]\nclass = 6'),
#  Text(0.24049513704686118, 0.7352941176470589, 'fixed acidity <= 12.35\ngini = 0.438\nsamples = 26\nvalue = [0, 1, 3, 19, 3, 0]\nclass = 6'),
#  Text(0.21927497789566755, 0.6764705882352942, 'residual sugar <= 1.65\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 3, 18, 0, 0]\nclass = 6'),
#  Text(0.21220159151193635, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.22634836427939875, 0.6176470588235294, 'density <= 1.0\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 2, 18, 0, 0]\nclass = 6'),
#  Text(0.21927497789566755, 0.5588235294117647, 'sulphates <= 0.52\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 1, 18, 0, 0]\nclass = 6'),
#  Text(0.21220159151193635, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.22634836427939875, 0.5, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]\nclass = 6'),
#  Text(0.23342175066312998, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.26171529619805484, 0.6764705882352942, 'sulphates <= 0.825\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 1, 3, 0]\nclass = 7'),
#  Text(0.2546419098143236, 0.6176470588235294, 'free sulfur dioxide <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.2475685234305924, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.26171529619805484, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.268788682581786, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(0.3041556145004421, 0.7352941176470589, 'pH <= 3.165\ngini = 0.583\nsamples = 12\nvalue = [1, 0, 7, 3, 0, 1]\nclass = 5'),
#  Text(0.29000884173297964, 0.6764705882352942, 'volatile acidity <= 0.335\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 7, 1, 0, 1]\nclass = 5'),
#  Text(0.28293545534924847, 0.6176470588235294, 'volatile acidity <= 0.29\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]\nclass = 6'),
#  Text(0.27586206896551724, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.29000884173297964, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.29708222811671087, 0.6176470588235294, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]\nclass = 5'),
#  Text(0.3183023872679045, 0.6764705882352942, 'chlorides <= 0.081\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.3112290008841733, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.3253757736516357, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.3837312113174182, 0.8529411764705882, 'chlorides <= 0.539\ngini = 0.271\nsamples = 90\nvalue = [0, 3, 76, 11, 0, 0]\nclass = 5'),
#  Text(0.376657824933687, 0.7941176470588235, 'pH <= 3.335\ngini = 0.255\nsamples = 89\nvalue = [0, 2, 76, 11, 0, 0]\nclass = 5'),
#  Text(0.34659593280282935, 0.7352941176470589, 'chlorides <= 0.067\ngini = 0.176\nsamples = 73\nvalue = [0, 1, 66, 6, 0, 0]\nclass = 5'),
#  Text(0.3395225464190981, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.3536693191865606, 0.6764705882352942, 'residual sugar <= 1.55\ngini = 0.155\nsamples = 72\nvalue = [0, 1, 66, 5, 0, 0]\nclass = 5'),
#  Text(0.3395225464190981, 0.6176470588235294, 'total sulfur dioxide <= 107.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.33244916003536695, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.34659593280282935, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.367816091954023, 0.6176470588235294, 'density <= 0.996\ngini = 0.133\nsamples = 70\nvalue = [0, 0, 65, 5, 0, 0]\nclass = 5'),
#  Text(0.36074270557029176, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.3748894783377542, 0.5588235294117647, 'sulphates <= 1.6\ngini = 0.109\nsamples = 69\nvalue = [0, 0, 65, 4, 0, 0]\nclass = 5'),
#  Text(0.36074270557029176, 0.5, 'pH <= 3.265\ngini = 0.086\nsamples = 67\nvalue = [0, 0, 64, 3, 0, 0]\nclass = 5'),
#  Text(0.3536693191865606, 0.4411764705882353, 'gini = 0.0\nsamples = 46\nvalue = [0, 0, 46, 0, 0, 0]\nclass = 5'),
#  Text(0.367816091954023, 0.4411764705882353, 'free sulfur dioxide <= 33.5\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 18, 3, 0, 0]\nclass = 5'),
#  Text(0.36074270557029176, 0.38235294117647056, 'volatile acidity <= 0.545\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]\nclass = 5'),
#  Text(0.3536693191865606, 0.3235294117647059, 'free sulfur dioxide <= 21.5\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]\nclass = 5'),
#  Text(0.34659593280282935, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.36074270557029176, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.367816091954023, 0.3235294117647059, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]\nclass = 5'),
#  Text(0.3748894783377542, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.3890362511052166, 0.5, 'pH <= 2.985\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.3819628647214854, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.39610963748894784, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.40671971706454463, 0.7352941176470589, 'citric acid <= 0.145\ngini = 0.508\nsamples = 16\nvalue = [0, 1, 10, 5, 0, 0]\nclass = 5'),
#  Text(0.3890362511052166, 0.6764705882352942, 'sulphates <= 0.57\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.3819628647214854, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.39610963748894784, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.4244031830238727, 0.6764705882352942, 'fixed acidity <= 7.9\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3, 0, 0]\nclass = 5'),
#  Text(0.41025641025641024, 0.6176470588235294, 'pH <= 3.565\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]\nclass = 5'),
#  Text(0.40318302387267907, 0.5588235294117647, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]\nclass = 5'),
#  Text(0.41732979664014147, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.4385499557913351, 0.6176470588235294, 'volatile acidity <= 0.44\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.43147656940760387, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.44562334217506633, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.39080459770114945, 0.7941176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6132156277630415, 0.9117647058823529, 'sulphates <= 0.545\ngini = 0.657\nsamples = 241\nvalue = [0, 4, 72, 112, 46, 7]\nclass = 6'),
#  Text(0.46684350132625996, 0.8529411764705882, 'chlorides <= 0.08\ngini = 0.408\nsamples = 32\nvalue = [0, 2, 24, 5, 1, 0]\nclass = 5'),
#  Text(0.45977011494252873, 0.7941176470588235, 'density <= 0.995\ngini = 0.675\nsamples = 13\nvalue = [0, 2, 5, 5, 1, 0]\nclass = 5'),
#  Text(0.44562334217506633, 0.7352941176470589, 'volatile acidity <= 0.835\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1, 0]\nclass = 4'),
#  Text(0.4385499557913351, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.4526967285587975, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.4739168877099912, 0.7352941176470589, 'volatile acidity <= 0.475\ngini = 0.5\nsamples = 10\nvalue = [0, 0, 5, 5, 0, 0]\nclass = 5'),
#  Text(0.46684350132625996, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.48099027409372236, 0.6764705882352942, 'fixed acidity <= 7.05\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]\nclass = 5'),
#  Text(0.4739168877099912, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.4880636604774536, 0.6176470588235294, 'density <= 0.998\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]\nclass = 5'),
#  Text(0.48099027409372236, 0.5588235294117647, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.4951370468611848, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.4739168877099912, 0.7941176470588235, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]\nclass = 5'),
#  Text(0.7595877541998232, 0.8529411764705882, 'sulphates <= 0.705\ngini = 0.638\nsamples = 209\nvalue = [0, 2, 48, 107, 45, 7]\nclass = 6'),
#  Text(0.6195291777188329, 0.7941176470588235, 'citric acid <= 0.745\ngini = 0.53\nsamples = 100\nvalue = [0, 2, 23, 64, 8, 3]\nclass = 6'),
#  Text(0.6124557913351016, 0.7352941176470589, 'pH <= 3.485\ngini = 0.513\nsamples = 98\nvalue = [0, 2, 23, 64, 6, 3]\nclass = 6'),
#  Text(0.5432139699381079, 0.6764705882352942, 'pH <= 3.055\ngini = 0.45\nsamples = 83\nvalue = [0, 1, 17, 59, 3, 3]\nclass = 6'),
#  Text(0.5163572060123784, 0.6176470588235294, 'total sulfur dioxide <= 24.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.5092838196286472, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5234305923961097, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.5700707338638373, 0.6176470588235294, 'free sulfur dioxide <= 5.5\ngini = 0.427\nsamples = 79\nvalue = [0, 1, 14, 58, 3, 3]\nclass = 6'),
#  Text(0.537577365163572, 0.5588235294117647, 'density <= 0.998\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 3, 3, 0, 2]\nclass = 5'),
#  Text(0.5305039787798409, 0.5, 'pH <= 3.18\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 0, 2]\nclass = 6'),
#  Text(0.5234305923961097, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]\nclass = 8'),
#  Text(0.537577365163572, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.5446507515473032, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.6025641025641025, 0.5588235294117647, 'pH <= 3.385\ngini = 0.374\nsamples = 71\nvalue = [0, 1, 11, 55, 3, 1]\nclass = 6'),
#  Text(0.5587975243147657, 0.5, 'residual sugar <= 4.65\ngini = 0.324\nsamples = 54\nvalue = [0, 1, 5, 44, 3, 1]\nclass = 6'),
#  Text(0.5517241379310345, 0.4411764705882353, 'citric acid <= 0.035\ngini = 0.298\nsamples = 53\nvalue = [0, 1, 5, 44, 3, 0]\nclass = 6'),
#  Text(0.5446507515473032, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5587975243147657, 0.38235294117647056, 'density <= 1.0\ngini = 0.274\nsamples = 52\nvalue = [0, 1, 4, 44, 3, 0]\nclass = 6'),
#  Text(0.5278514588859416, 0.3235294117647059, 'citric acid <= 0.305\ngini = 0.228\nsamples = 48\nvalue = [0, 1, 3, 42, 2, 0]\nclass = 6'),
#  Text(0.5048629531388152, 0.2647058823529412, 'pH <= 3.155\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 1, 23, 0, 0]\nclass = 6'),
#  Text(0.497789566755084, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5119363395225465, 0.20588235294117646, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0, 0]\nclass = 6'),
#  Text(0.5508399646330681, 0.2647058823529412, 'alcohol <= 10.45\ngini = 0.358\nsamples = 24\nvalue = [0, 1, 2, 19, 2, 0]\nclass = 6'),
#  Text(0.5260831122900088, 0.20588235294117646, 'free sulfur dioxide <= 11.0\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 1, 1, 0]\nclass = 4'),
#  Text(0.5190097259062776, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.53315649867374, 0.14705882352941177, 'citric acid <= 0.315\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 1, 0]\nclass = 4'),
#  Text(0.5260831122900088, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.5402298850574713, 0.08823529411764706, 'citric acid <= 0.34\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.53315649867374, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5473032714412025, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.5755968169761273, 0.20588235294117646, 'volatile acidity <= 0.3\ngini = 0.185\nsamples = 20\nvalue = [0, 0, 1, 18, 1, 0]\nclass = 6'),
#  Text(0.5614500442086648, 0.14705882352941177, 'volatile acidity <= 0.235\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.5543766578249337, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5685234305923961, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5897435897435898, 0.14705882352941177, 'density <= 0.996\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 0, 17, 1, 0]\nclass = 6'),
#  Text(0.5826702033598585, 0.08823529411764706, 'chlorides <= 0.065\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.5755968169761273, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5897435897435898, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.596816976127321, 0.08823529411764706, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]\nclass = 6'),
#  Text(0.5897435897435898, 0.3235294117647059, 'chlorides <= 0.091\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]\nclass = 6'),
#  Text(0.5826702033598585, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.596816976127321, 0.2647058823529412, 'chlorides <= 0.098\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.5897435897435898, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.6038903625110522, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5658709106984969, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.6463306808134395, 0.5, 'volatile acidity <= 0.695\ngini = 0.457\nsamples = 17\nvalue = [0, 0, 6, 11, 0, 0]\nclass = 6'),
#  Text(0.6392572944297082, 0.4411764705882353, 'total sulfur dioxide <= 53.5\ngini = 0.391\nsamples = 15\nvalue = [0, 0, 4, 11, 0, 0]\nclass = 6'),
#  Text(0.6251105216622458, 0.38235294117647056, 'pH <= 3.415\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]\nclass = 6'),
#  Text(0.6180371352785146, 0.3235294117647059, 'density <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.6109637488947833, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.6251105216622458, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.632183908045977, 0.3235294117647059, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(0.6534040671971706, 0.38235294117647056, 'free sulfur dioxide <= 27.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.6463306808134395, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.6604774535809018, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.6534040671971706, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.6816976127320955, 0.6764705882352942, 'sulphates <= 0.625\ngini = 0.684\nsamples = 15\nvalue = [0, 1, 6, 5, 3, 0]\nclass = 5'),
#  Text(0.6746242263483643, 0.6176470588235294, 'free sulfur dioxide <= 18.0\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 0, 5, 3, 0]\nclass = 6'),
#  Text(0.667550839964633, 0.5588235294117647, 'chlorides <= 0.056\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.6604774535809018, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6746242263483643, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.6816976127320955, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(0.6887709991158267, 0.6176470588235294, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]\nclass = 5'),
#  Text(0.6266025641025641, 0.7352941176470589, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.8996463306808135, 0.7941176470588235, 'sulphates <= 0.925\ngini = 0.675\nsamples = 109\nvalue = [0, 0, 25, 43, 37, 4]\nclass = 6'),
#  Text(0.8275862068965517, 0.7352941176470589, 'total sulfur dioxide <= 62.0\ngini = 0.687\nsamples = 88\nvalue = [0, 0, 24, 26, 34, 4]\nclass = 7'),
#  Text(0.7541998231653404, 0.6764705882352942, 'alcohol <= 10.45\ngini = 0.632\nsamples = 62\nvalue = [0, 0, 8, 21, 30, 3]\nclass = 7'),
#  Text(0.7099911582670203, 0.6176470588235294, 'free sulfur dioxide <= 10.5\ngini = 0.521\nsamples = 19\nvalue = [0, 0, 2, 12, 5, 0]\nclass = 6'),
#  Text(0.695844385499558, 0.5588235294117647, 'pH <= 3.23\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 2, 5, 0]\nclass = 7'),
#  Text(0.6887709991158267, 0.5, 'sulphates <= 0.86\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 0, 5, 0]\nclass = 7'),
#  Text(0.6816976127320955, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 7'),
#  Text(0.695844385499558, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7029177718832891, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.7241379310344828, 0.5588235294117647, 'volatile acidity <= 0.632\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]\nclass = 6'),
#  Text(0.7170645446507515, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(0.731211317418214, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7984084880636605, 0.6176470588235294, 'pH <= 3.33\ngini = 0.594\nsamples = 43\nvalue = [0, 0, 6, 9, 25, 3]\nclass = 7'),
#  Text(0.7736516357206012, 0.5588235294117647, 'citric acid <= 0.615\ngini = 0.678\nsamples = 30\nvalue = [0, 0, 6, 9, 13, 2]\nclass = 7'),
#  Text(0.7453580901856764, 0.5, 'volatile acidity <= 0.415\ngini = 0.711\nsamples = 22\nvalue = [0, 0, 6, 8, 6, 2]\nclass = 6'),
#  Text(0.7099911582670203, 0.4411764705882353, 'total sulfur dioxide <= 18.5\ngini = 0.678\nsamples = 11\nvalue = [0, 0, 3, 1, 5, 2]\nclass = 7'),
#  Text(0.695844385499558, 0.38235294117647056, 'alcohol <= 11.15\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 0, 2]\nclass = 5'),
#  Text(0.6887709991158267, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.7029177718832891, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]\nclass = 8'),
#  Text(0.7241379310344828, 0.38235294117647056, 'fixed acidity <= 11.25\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 1, 5, 0]\nclass = 7'),
#  Text(0.7170645446507515, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 7'),
#  Text(0.731211317418214, 0.3235294117647059, 'free sulfur dioxide <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.7241379310344828, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.7382847038019452, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7807250221043325, 0.4411764705882353, 'residual sugar <= 3.05\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 3, 7, 1, 0]\nclass = 6'),
#  Text(0.76657824933687, 0.38235294117647056, 'fixed acidity <= 12.2\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]\nclass = 6'),
#  Text(0.7595048629531388, 0.3235294117647059, 'total sulfur dioxide <= 17.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]\nclass = 6'),
#  Text(0.7524314765694076, 0.2647058823529412, 'residual sugar <= 2.35\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.7453580901856764, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7595048629531388, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.76657824933687, 0.2647058823529412, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(0.7736516357206012, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7948717948717948, 0.38235294117647056, 'sulphates <= 0.835\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.7877984084880637, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.801945181255526, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.801945181255526, 0.5, 'total sulfur dioxide <= 38.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]\nclass = 7'),
#  Text(0.7948717948717948, 0.4411764705882353, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]\nclass = 7'),
#  Text(0.8090185676392573, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8231653404067197, 0.5588235294117647, 'alcohol <= 12.65\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 0, 0, 12, 1]\nclass = 7'),
#  Text(0.8160919540229885, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 11, 0]\nclass = 7'),
#  Text(0.830238726790451, 0.5, 'volatile acidity <= 0.38\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]\nclass = 7'),
#  Text(0.8231653404067197, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.8373121131741822, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.900972590627763, 0.6764705882352942, 'alcohol <= 11.35\ngini = 0.559\nsamples = 26\nvalue = [0, 0, 16, 5, 4, 1]\nclass = 5'),
#  Text(0.865605658709107, 0.6176470588235294, 'volatile acidity <= 0.33\ngini = 0.29\nsamples = 18\nvalue = [0, 0, 15, 1, 2, 0]\nclass = 5'),
#  Text(0.8514588859416445, 0.5588235294117647, 'pH <= 3.29\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]\nclass = 7'),
#  Text(0.8443854995579133, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.8585322723253758, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.8797524314765695, 0.5588235294117647, 'density <= 0.999\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]\nclass = 5'),
#  Text(0.8726790450928382, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]\nclass = 5'),
#  Text(0.8868258178603006, 0.5, 'free sulfur dioxide <= 28.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.8797524314765695, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8938992042440318, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9363395225464191, 0.6176470588235294, 'fixed acidity <= 9.1\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 1, 4, 2, 1]\nclass = 6'),
#  Text(0.9221927497789567, 0.5588235294117647, 'chlorides <= 0.048\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 4, 1, 1]\nclass = 6'),
#  Text(0.9151193633952255, 0.5, 'alcohol <= 12.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]\nclass = 7'),
#  Text(0.9080459770114943, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.9221927497789567, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.9292661361626879, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.9504862953138815, 0.5588235294117647, 'fixed acidity <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.9434129089301503, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.9575596816976127, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9717064544650752, 0.7352941176470589, 'total sulfur dioxide <= 18.5\ngini = 0.322\nsamples = 21\nvalue = [0, 0, 1, 17, 3, 0]\nclass = 6'),
#  Text(0.9575596816976127, 0.6764705882352942, 'pH <= 3.11\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]\nclass = 7'),
#  Text(0.9504862953138815, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.964633068081344, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(0.9858532272325375, 0.6764705882352942, 'chlorides <= 0.071\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 1, 16, 0, 0]\nclass = 6'),
#  Text(0.9787798408488063, 0.6176470588235294, 'residual sugar <= 2.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.9717064544650752, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.9858532272325375, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9929266136162688, 0.6176470588235294, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]\nclass = 6')]

# %% [markdown]
# - Performing Post Prunning on level 3 where there are 20 records for class 5 and 1 record for class 6.
#     - Removing level 3 to control complexity of the tree

# %%
# Checking train and test accuracy
dt_model1.predict(x1)
# Out:
# array([5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5,
#        5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5,
#        5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5,
#        5, 5, 5, 6, 6, 5, 5, 4, 5, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5,
#        5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5,
#        5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5,
#        5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 4, 5, 5,
#        5, 5, 5, 5, 5, 6, 5, 4, 6, 5, 5, 5, 5, 4, 6, 5, 4, 6, 6, 6, 5, 5,
#        5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6,
#        7, 4, 7, 5, 5, 5, 6, 7, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5,
#        6, 5, 5, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6,
#        6, 7, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 5, 4, 5, 5,
#        5, 7, 4, 8, 6, 6, 6, 6, 5, 5, 5, 6, 6, 6, 8, 7, 6, 7, 5, 7, 5, 5,
#        6, 6, 7, 5, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5, 6,
#        6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5,
#        6, 6, 6, 5, 7, 7, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 6, 6, 6, 6, 6,
#        5, 5, 6, 6, 5, 7, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 5, 7, 5, 6, 6, 5,
#        6, 7, 6, 7, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 8, 6, 5, 5, 5, 7,
#        5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 7, 6, 4, 6, 5, 5, 7, 5, 5, 6, 5,
#        6, 5, 7, 7, 5, 7, 5, 7, 6, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 5,
#        8, 6, 7, 7, 7, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 8, 5, 5, 7, 3, 6, 5,
#        5, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 8, 5, 5,
#        6, 5, 5, 6, 7, 6, 6, 7, 7, 6, 6, 8, 6, 5, 8, 6], dtype=int64)

# %%
dt_model1.score(x1,y1)
# Out:
# 1.0

# %%
dt_model1.score(x_test,y_test)
# Out:
# 0.6025

# %% [markdown]
# Here the model is overfitted as we are getting higher accuracy and on random sample as input its giving lower accuracy.
#
# - Here lower accuracy isnt a great issue as compared to overfitting so we would resolve overfitting here.

# %%
path = dt_model1.cost_complexity_pruning_path(x1,y1)

# %%
path
# Out:
# {'ccp_alphas': array([0.        , 0.00166667, 0.00175   , 0.00181818, 0.00184615,
#         0.00186667, 0.00188235, 0.00192308, 0.002     , 0.002     ,
#         0.002     , 0.002     , 0.002     , 0.002     , 0.002     ,
#         0.002     , 0.002     , 0.00203333, 0.00247552, 0.00261111,
#         0.00262769, 0.00266667, 0.00266667, 0.00266667, 0.00266667,
#         0.00266667, 0.00266667, 0.00266667, 0.00266667, 0.00272222,
#         0.00283333, 0.003     , 0.003     , 0.003     , 0.003     ,
#         0.00304762, 0.00305051, 0.00308418, 0.00328205, 0.00333333,
#         0.00333333, 0.00334032, 0.00336606, 0.00342857, 0.00343316,
#         0.0035    , 0.0035    , 0.0036    , 0.00363636, 0.00373809,
#         0.0038    , 0.0038237 , 0.004     , 0.00404444, 0.00428571,
#         0.00437662, 0.00462338, 0.00465709, 0.00466667, 0.0048    ,
#         0.00495726, 0.00504242, 0.00508235, 0.00509091, 0.00510606,
#         0.00516667, 0.00568485, 0.00589394, 0.00656364, 0.00671079,
#         0.0067591 , 0.00688352, 0.00688889, 0.007     , 0.00701299,
#         0.00706234, 0.00725171, 0.00759048, 0.00771182, 0.00786235,
#         0.00813248, 0.00858654, 0.01285167, 0.01310242, 0.01335452,
#         0.01789286, 0.02414791, 0.04600728]),
#  'impurities': array([0.        , 0.00333333, 0.00683333, 0.0104697 , 0.014162  ,
#         0.01789534, 0.02166004, 0.0255062 , 0.0275062 , 0.0295062 ,
#         0.0315062 , 0.0335062 , 0.0395062 , 0.0415062 , 0.0435062 ,
#         0.0455062 , 0.0475062 , 0.05157286, 0.05899944, 0.07727722,
#         0.09041568, 0.09308234, 0.09574901, 0.09841568, 0.10108234,
#         0.10374901, 0.10641568, 0.10908234, 0.11174901, 0.11447123,
#         0.12297123, 0.12597123, 0.12897123, 0.13197123, 0.13497123,
#         0.13801885, 0.14106936, 0.14415354, 0.15071764, 0.15405097,
#         0.15738431, 0.16072463, 0.16409069, 0.1743764 , 0.17780955,
#         0.18130955, 0.18480955, 0.18840955, 0.19204592, 0.2032602 ,
#         0.2070602 , 0.2185313 , 0.2225313 , 0.22657574, 0.23086146,
#         0.23523808, 0.23986146, 0.25848983, 0.26782316, 0.27262316,
#         0.28749496, 0.29253738, 0.29761974, 0.30271064, 0.3078167 ,
#         0.31298337, 0.31866822, 0.32456216, 0.3311258 , 0.33783659,
#         0.34459569, 0.35147921, 0.3583681 , 0.3653681 , 0.38640708,
#         0.40053176, 0.40778347, 0.42296443, 0.44609989, 0.45396224,
#         0.46209471, 0.47068125, 0.4963846 , 0.52258943, 0.53594395,
#         0.55383681, 0.57798472, 0.623992  ])}

# %%
ccp_alpha = path.ccp_alphas

# %%
# Passsing different ccp alphas
dt_model2 = []
for ccp in ccp_alpha:
    dt_m = DecisionTreeClassifier(ccp_alpha=ccp)
    dt_m.fit(x1,y1)
    dt_model2.append(dt_m)

# %%
dt_model2
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.0016666666666666668),
#  DecisionTreeClassifier(ccp_alpha=0.00175),
#  DecisionTreeClassifier(ccp_alpha=0.0018181818181818184),
#  DecisionTreeClassifier(ccp_alpha=0.0018461538461538455),
#  DecisionTreeClassifier(ccp_alpha=0.001866666666666667),
#  DecisionTreeClassifier(ccp_alpha=0.001882352941176471),
#  DecisionTreeClassifier(ccp_alpha=0.0019230769230769243),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002033333333333334),
#  DecisionTreeClassifier(ccp_alpha=0.0024755244755244737),
#  DecisionTreeClassifier(ccp_alpha=0.0026111111111111114),
#  DecisionTreeClassifier(ccp_alpha=0.0026276923076923083),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.002722222222222221),
#  DecisionTreeClassifier(ccp_alpha=0.0028333333333333335),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.0030476190476190477),
#  DecisionTreeClassifier(ccp_alpha=0.0030505050505050518),
#  DecisionTreeClassifier(ccp_alpha=0.0030841799709724164),
#  DecisionTreeClassifier(ccp_alpha=0.0032820512820512827),
#  DecisionTreeClassifier(ccp_alpha=0.0033333333333333335),
#  DecisionTreeClassifier(ccp_alpha=0.0033333333333333335),
#  DecisionTreeClassifier(ccp_alpha=0.0033403214535289993),
#  DecisionTreeClassifier(ccp_alpha=0.0033660578386605737),
#  DecisionTreeClassifier(ccp_alpha=0.0034285714285714297),
#  DecisionTreeClassifier(ccp_alpha=0.003433155080213907),
#  DecisionTreeClassifier(ccp_alpha=0.0035),
#  DecisionTreeClassifier(ccp_alpha=0.0035),
#  DecisionTreeClassifier(ccp_alpha=0.0036000000000000008),
#  DecisionTreeClassifier(ccp_alpha=0.003636363636363637),
#  DecisionTreeClassifier(ccp_alpha=0.0037380946805604365),
#  DecisionTreeClassifier(ccp_alpha=0.003799999999999999),
#  DecisionTreeClassifier(ccp_alpha=0.003823698645294892),
#  DecisionTreeClassifier(ccp_alpha=0.004),
#  DecisionTreeClassifier(ccp_alpha=0.0040444444444444425),
#  DecisionTreeClassifier(ccp_alpha=0.004285714285714287),
#  DecisionTreeClassifier(ccp_alpha=0.004376623376623378),
#  DecisionTreeClassifier(ccp_alpha=0.004623376623376621),
#  DecisionTreeClassifier(ccp_alpha=0.004657093161377905),
#  DecisionTreeClassifier(ccp_alpha=0.004666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0048),
#  DecisionTreeClassifier(ccp_alpha=0.0049572649572649586),
#  DecisionTreeClassifier(ccp_alpha=0.005042424242424239),
#  DecisionTreeClassifier(ccp_alpha=0.005082352941176471),
#  DecisionTreeClassifier(ccp_alpha=0.005090909090909097),
#  DecisionTreeClassifier(ccp_alpha=0.005106060606060606),
#  DecisionTreeClassifier(ccp_alpha=0.005166666666666667),
#  DecisionTreeClassifier(ccp_alpha=0.005684848484848487),
#  DecisionTreeClassifier(ccp_alpha=0.005893939393939396),
#  DecisionTreeClassifier(ccp_alpha=0.0065636363636363635),
#  DecisionTreeClassifier(ccp_alpha=0.0067107930828861),
#  DecisionTreeClassifier(ccp_alpha=0.0067591036414565795),
#  DecisionTreeClassifier(ccp_alpha=0.006883516483516483),
#  DecisionTreeClassifier(ccp_alpha=0.006888888888888889),
#  DecisionTreeClassifier(ccp_alpha=0.007000000000000001),
#  DecisionTreeClassifier(ccp_alpha=0.007012994199018301),
#  DecisionTreeClassifier(ccp_alpha=0.0070623376623376675),
#  DecisionTreeClassifier(ccp_alpha=0.007251712992889445),
#  DecisionTreeClassifier(ccp_alpha=0.00759048284798472),
#  DecisionTreeClassifier(ccp_alpha=0.007711817594170538),
#  DecisionTreeClassifier(ccp_alpha=0.007862348178137649),
#  DecisionTreeClassifier(ccp_alpha=0.008132478632478634),
#  DecisionTreeClassifier(ccp_alpha=0.008586538461538458),
#  DecisionTreeClassifier(ccp_alpha=0.012851672777488471),
#  DecisionTreeClassifier(ccp_alpha=0.013102415587766272),
#  DecisionTreeClassifier(ccp_alpha=0.013354516483034151),
#  DecisionTreeClassifier(ccp_alpha=0.01789286463132611),
#  DecisionTreeClassifier(ccp_alpha=0.024147905954059024),
#  DecisionTreeClassifier(ccp_alpha=0.04600728380781505)]

# %% [markdown]
# First one has ccp_alpha = 0
# <br>
#
# In total we have built 8 models so far

# %%
"""train_score = dt_model1.score(x1,y1) fo
test_score = dt_model1.score()"""
# Out:
# 'train_score = dt_model1.score(x1,y1) fo\ntest_score = dt_model1.score()'

# %%
train_scoreCPP = [i.score(x1,y1) for i in dt_model2]

# %%
test_scoreCPP = [i.score(x_test,y_test) for i in dt_model2]

# %%
test_scoreCPP
# Out:
# [0.595,
#  0.61,
#  0.5925,
#  0.565,
#  0.6175,
#  0.6,
#  0.6,
#  0.6025,
#  0.56,
#  0.5825,
#  0.6125,
#  0.59,
#  0.6025,
#  0.58,
#  0.5675,
#  0.59,
#  0.595,
#  0.6025,
#  0.6,
#  0.605,
#  0.6025,
#  0.59,
#  0.585,
#  0.6025,
#  0.6025,
#  0.6,
#  0.595,
#  0.61,
#  0.595,
#  0.6,
#  0.6,
#  0.5825,
#  0.585,
#  0.59,
#  0.61,
#  0.5975,
#  0.5975,
#  0.61,
#  0.6025,
#  0.61,
#  0.6025,
#  0.6175,
#  0.615,
#  0.61,
#  0.6075,
#  0.6,
#  0.6075,
#  0.595,
#  0.6,
#  0.6175,
#  0.6025,
#  0.62,
#  0.6175,
#  0.615,
#  0.6075,
#  0.605,
#  0.61,
#  0.605,
#  0.61,
#  0.61,
#  0.6125,
#  0.6175,
#  0.6175,
#  0.61,
#  0.605,
#  0.6075,
#  0.5975,
#  0.59,
#  0.59,
#  0.59,
#  0.5825,
#  0.585,
#  0.59,
#  0.5875,
#  0.585,
#  0.5825,
#  0.5825,
#  0.56,
#  0.5725,
#  0.5625,
#  0.555,
#  0.555,
#  0.54,
#  0.5775,
#  0.5775,
#  0.5775,
#  0.545,
#  0.4225]

# %%
train_scoreCPP
# Out:
# [1.0,
#  0.998,
#  0.998,
#  0.996,
#  0.994,
#  0.992,
#  0.99,
#  0.986,
#  0.964,
#  0.962,
#  0.962,
#  0.96,
#  0.966,
#  0.96,
#  0.96,
#  0.962,
#  0.962,
#  0.96,
#  0.96,
#  0.95,
#  0.944,
#  0.93,
#  0.93,
#  0.928,
#  0.932,
#  0.932,
#  0.93,
#  0.932,
#  0.932,
#  0.926,
#  0.928,
#  0.92,
#  0.916,
#  0.92,
#  0.916,
#  0.912,
#  0.906,
#  0.908,
#  0.906,
#  0.902,
#  0.9,
#  0.9,
#  0.892,
#  0.892,
#  0.89,
#  0.886,
#  0.886,
#  0.882,
#  0.876,
#  0.868,
#  0.868,
#  0.86,
#  0.854,
#  0.854,
#  0.856,
#  0.852,
#  0.838,
#  0.824,
#  0.828,
#  0.824,
#  0.81,
#  0.804,
#  0.802,
#  0.794,
#  0.79,
#  0.786,
#  0.784,
#  0.78,
#  0.776,
#  0.776,
#  0.772,
#  0.768,
#  0.762,
#  0.758,
#  0.742,
#  0.728,
#  0.718,
#  0.698,
#  0.69,
#  0.682,
#  0.676,
#  0.676,
#  0.636,
#  0.596,
#  0.596,
#  0.596,
#  0.558,
#  0.478]

# %%
fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alpha, train_scoreCPP, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alpha, test_scoreCPP, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# Hence Overfitting is reduced through increased training dataset.
#
# <br>
# So we can say our model has reduced overfitting for cpp>0.02 so we would create model again with those cpp's

# %%
dt_model_ccp = DecisionTreeClassifier(random_state=0 , ccp_alpha=.014)
dt_model_ccp.fit(x1,y1)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.014, random_state=0)

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model_ccp,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[10] <= 9.85\ngini = 0.624\nsamples = 500\nvalue = [1, 16, 239, 184, 52, 8]'),
#  Text(0.25, 0.5, 'x[6] <= 62.5\ngini = 0.504\nsamples = 259\nvalue = [1, 12, 167, 72, 6, 1]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.576\nsamples = 169\nvalue = [1, 9, 91, 61, 6, 1]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.271\nsamples = 90\nvalue = [0, 3, 76, 11, 0, 0]'),
#  Text(0.75, 0.5, 'x[9] <= 0.545\ngini = 0.657\nsamples = 241\nvalue = [0, 4, 72, 112, 46, 7]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.408\nsamples = 32\nvalue = [0, 2, 24, 5, 1, 0]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.638\nsamples = 209\nvalue = [0, 2, 48, 107, 45, 7]')]

# %% [markdown]
# Now we are able to create less complex tree through Post Prunning while tunning ccp alpha as a hyperparameter
#
# <br>
# We can say Post Prunning as chopping off branches

# %%
dt_model_cpp.score(x1,y1)
# Out:
# 0.478

# %%
dt_model_cpp.score(x_test,y_test)
# Out:
# 0.4225

# %% [markdown]
# Now we can say we are able to reduce overfitting by bringing training and testing accuracies closer.

# %% [markdown]
# Grid and Random Search CV will try to find best parameters value in sklearn.decisiontreeclassifier just like how we had tuned "ccp" it will tune other parameters to find best parameter.

# %% [markdown]
# But not one by one just like how we did as it would take time so it will Grid and Random Search CV will automatically select the best hyperparameter based upon cross validation (CV) split that it will do by dividing "TRAINING" data into 5 different parameters where it will divide 4 dataset into training and 1 into testing and it will keep on doing that.

# %%
grid_param = {
    "criterion" : ["gini","entropy"],
    "splitter" : ["best","random"],
    "max_depth" : range(2,40,1),
    "min_samples_split" : range(2,10,1),
    "min_samples_leaf" : range(1,10,1),
}

# %%
grid_ccp = GridSearchCV(estimator=dt_model_ccp, param_grid=grid_param, cv=5, n_jobs=-1)

# %%
grid_ccp.fit(x1,y1)
# Out:
# c:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.014, random_state=0),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 40),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
grid_ccp.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 15,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
dt_cpp_new = DecisionTreeClassifier(criterion="entropy",max_depth=15,min_samples_leaf=2,min_samples_split=2,splitter="random")

# %%
dt_cpp_new.fit(x1,y1)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=15, min_samples_leaf=2,
#                        splitter='random')

# %%
dt_cpp_new.score(x1,y1)
# Out:
# 0.864

# %%
dt_cpp_new.score(x_test,y_test)
# Out:
# 0.55

# %% [markdown]
# Even after performing hyperparameter tuning through GridSearchCV we are still getting overfitted model.
#
# <br>
# So we can say hyperparameter tuning wont always increase accuracy

# %%
dt_cpp_new = DecisionTreeClassifier(criterion="entropy",max_depth=15,min_samples_leaf=2,min_samples_split=2,splitter="random",ccp_alpha=0.104)

# %%
dt_cpp_new.fit(x1,y1)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.104, criterion='entropy', max_depth=15,
#                        min_samples_leaf=2, splitter='random')

# %%
dt_cpp_new.score(x1,y1)
# Out:
# 0.478

# %%
dt_cpp_new.score(x_test,y_test)
# Out:
# 0.4225

# %% [markdown]
# Difference between GridSearch and RandomSearch is that GridSearch will try all combinations for given parameters on the model but RandomSearch will always try random combinations but not all for the given parameters.
#
# <br>
# Apart from this there is no difference between Grid and RandomSearchCV

# %% [markdown]
# Duplicates row wont affect accuracy in Decision Tree as it would always split based upon the threshold and if multiple values for same class are there it will bundle them and increase the "values" value in decision tree that we visualized.

# %% [markdown]
# We can do the same for ccp_alpha too with Random/GridSearchCV as its also a parameter.
