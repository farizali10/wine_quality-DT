# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score,roc_curve
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv("D:\Data-Science-D-drive\Practical Implementation ML Algos\winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#ProfileReport(df)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
set(df.quality)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
x = df.drop(columns="quality")

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y  = df[["quality"]]

# %%
y.head()
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
x_train , x_test, y_train,y_test = train_test_split(x,y,test_size = .25,random_state = 30)

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_model.predict(x_test)
# Out:
# array([6, 3, 6, 6, 6, 5, 6, 6, 7, 5, 6, 6, 6, 5, 7, 4, 5, 5, 7, 6, 5, 7,
#        5, 5, 5, 5, 8, 6, 5, 5, 6, 6, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 7, 5,
#        5, 7, 6, 6, 5, 6, 6, 8, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 7, 5, 7, 5,
#        5, 6, 5, 4, 6, 5, 5, 5, 6, 6, 7, 5, 6, 5, 6, 7, 6, 6, 5, 5, 5, 5,
#        5, 6, 5, 5, 6, 4, 6, 6, 4, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5,
#        5, 5, 5, 7, 7, 5, 6, 6, 5, 6, 6, 7, 7, 6, 7, 5, 6, 5, 6, 6, 6, 5,
#        6, 5, 7, 6, 5, 4, 7, 7, 5, 5, 6, 5, 5, 5, 5, 4, 6, 7, 5, 5, 5, 6,
#        5, 6, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 4, 5, 6, 6, 6, 6, 6, 6, 5, 6,
#        5, 5, 6, 6, 5, 6, 7, 5, 6, 5, 6, 6, 4, 7, 5, 5, 5, 7, 6, 5, 7, 6,
#        5, 6, 7, 5, 5, 5, 6, 7, 7, 6, 6, 6, 6, 5, 7, 5, 6, 5, 6, 5, 5, 6,
#        6, 6, 7, 6, 5, 6, 5, 5, 7, 5, 5, 6, 7, 7, 6, 5, 5, 7, 6, 6, 5, 6,
#        6, 6, 7, 6, 6, 7, 6, 5, 4, 7, 4, 6, 6, 5, 6, 6, 5, 6, 6, 5, 6, 6,
#        5, 6, 6, 4, 6, 6, 5, 3, 6, 7, 5, 5, 7, 6, 5, 5, 5, 4, 5, 6, 5, 6,
#        6, 5, 6, 6, 5, 6, 5, 8, 5, 6, 5, 6, 7, 6, 5, 6, 6, 5, 6, 5, 6, 6,
#        6, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 5, 6, 6, 6, 4, 6, 5, 6, 5, 6, 5,
#        6, 6, 6, 5, 6, 4, 6, 5, 5, 5, 6, 7, 5, 6, 7, 4, 5, 6, 5, 6, 6, 6,
#        5, 5, 6, 5, 7, 5, 6, 6, 5, 7, 5, 5, 7, 5, 7, 7, 6, 6, 5, 5, 5, 6,
#        6, 6, 6, 6, 5, 5, 5, 6, 5, 6, 4, 6, 6, 5, 5, 6, 7, 6, 5, 6, 8, 6,
#        6, 6, 6, 6], dtype=int64)

# %%
dt_model.score(x_test,y_test)*100
# Out:
# 61.25000000000001

# %%
dt_ent = DecisionTreeClassifier(criterion='entropy')

# %%
dt_ent.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_ent.score(x_test,y_test)*100
# Out:
# 62.74999999999999

# %% [markdown]
# Genrating Meta File of the Model

# %%
outfile = dot_for_dt_ent = open("dt_ent.dot","w")
tree.export_graphviz(dt_ent,out_file=outfile, feature_names=x.columns)

# %%
dir()
# Out:
# ['DecisionTreeClassifier',
#  'GridSearchCV',
#  'In',
#  'Out',
#  'ProfileReport',
#  '_',
#  '_12',
#  '_13',
#  '_15',
#  '_16',
#  '_18',
#  '_19',
#  '_21',
#  '_22',
#  '_25',
#  '_26',
#  '_27',
#  '_29',
#  '_3',
#  '_30',
#  '_36',
#  '_37',
#  '_38',
#  '_4',
#  '_41',
#  '_42',
#  '_43',
#  '_46',
#  '_47',
#  '_48',
#  '_5',
#  '_50',
#  '_51',
#  '_55',
#  '_56',
#  '_57',
#  '_63',
#  '_64',
#  '_65',
#  '_67',
#  '_7',
#  '_70',
#  '_72',
#  '_73',
#  '_75',
#  '_77',
#  '_80',
#  '_81',
#  '_82',
#  '_84',
#  '_85',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
#  '_i64',
#  '_i65',
#  '_i66',
#  '_i67',
#  '_i68',
#  '_i69',
#  '_i7',
#  '_i70',
#  '_i71',
#  '_i72',
#  '_i73',
#  '_i74',
#  '_i75',
#  '_i76',
#  '_i77',
#  '_i78',
#  '_i79',
#  '_i8',
#  '_i80',
#  '_i81',
#  '_i82',
#  '_i83',
#  '_i84',
#  '_i85',
#  '_i86',
#  '_i87',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'accuracy_score',
#  'confusion_matrix',
#  'df',
#  'df1',
#  'dot_for_dt_ent',
#  'dt_ent',
#  'dt_model',
#  'dt_model1',
#  'exit',
#  'get_ipython',
#  'np',
#  'open',
#  'outfile',
#  'pd',
#  'plt',
#  'quit',
#  'roc_auc_score',
#  'roc_curve',
#  'sklearn',
#  'train_test_split',
#  'tree',
#  'x',
#  'x1',
#  'x_test',
#  'x_train',
#  'y',
#  'y1',
#  'y_test',
#  'y_train']

# %%
# Visualizing tree:
import sklearn
import matplotlib.pyplot as plt
from sklearn import tree
# %matplotlib inline

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %%
plt.figure(figsize=(20,20))
#tree.plot_tree(dt_model,filled=True)
# Out:
# [Text(0.5496423476528854, 0.9722222222222222, 'x[10] <= 10.35\ngini = 0.642\nsamples = 1199\nvalue = [8, 35, 512, 477, 153, 14]'),
#  Text(0.32378808677863913, 0.9166666666666666, 'x[6] <= 95.5\ngini = 0.528\nsamples = 666\nvalue = [6, 20, 406, 209, 23, 2]'),
#  Text(0.20227040267011198, 0.8611111111111112, 'x[9] <= 0.585\ngini = 0.554\nsamples = 584\nvalue = [6, 19, 332, 202, 23, 2]'),
#  Text(0.07437015503875968, 0.8055555555555556, 'x[6] <= 90.5\ngini = 0.468\nsamples = 261\nvalue = [3, 14, 179, 63, 2, 0]'),
#  Text(0.0521640826873385, 0.75, 'x[10] <= 9.075\ngini = 0.453\nsamples = 250\nvalue = [3, 14, 176, 55, 2, 0]'),
#  Text(0.01808785529715762, 0.6944444444444444, 'x[6] <= 39.0\ngini = 0.604\nsamples = 15\nvalue = [0, 2, 6, 7, 0, 0]'),
#  Text(0.01119724375538329, 0.6388888888888888, 'x[6] <= 29.5\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 1, 6, 0, 0]'),
#  Text(0.007751937984496124, 0.5833333333333334, 'x[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.004306632213608958, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.01119724375538329, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.014642549526270457, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.024978466838931956, 0.6388888888888888, 'x[9] <= 0.485\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 1, 0, 0]'),
#  Text(0.02153316106804479, 0.5833333333333334, 'x[1] <= 0.445\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.01808785529715762, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.024978466838931956, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.028423772609819122, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.08624031007751938, 0.6944444444444444, 'x[10] <= 9.85\ngini = 0.432\nsamples = 235\nvalue = [3, 12, 170, 48, 2, 0]'),
#  Text(0.05878552971576227, 0.6388888888888888, 'x[4] <= 0.08\ngini = 0.384\nsamples = 176\nvalue = [2, 11, 135, 27, 1, 0]'),
#  Text(0.04263565891472868, 0.5833333333333334, 'x[0] <= 10.05\ngini = 0.497\nsamples = 83\nvalue = [1, 6, 55, 20, 1, 0]'),
#  Text(0.03186907838070629, 0.5277777777777778, 'x[1] <= 0.42\ngini = 0.456\nsamples = 79\nvalue = [1, 3, 55, 19, 1, 0]'),
#  Text(0.020671834625323, 0.4722222222222222, 'x[9] <= 0.555\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.017226528854435832, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.024117140396210164, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.04306632213608958, 0.4722222222222222, 'x[1] <= 0.862\ngini = 0.423\nsamples = 71\nvalue = [1, 3, 52, 14, 1, 0]'),
#  Text(0.031007751937984496, 0.4166666666666667, 'x[0] <= 7.65\ngini = 0.376\nsamples = 67\nvalue = [0, 1, 51, 14, 1, 0]'),
#  Text(0.017226528854435832, 0.3611111111111111, 'x[7] <= 0.999\ngini = 0.208\nsamples = 34\nvalue = [0, 0, 30, 4, 0, 0]'),
#  Text(0.013781223083548665, 0.3055555555555556, 'x[8] <= 3.565\ngini = 0.165\nsamples = 33\nvalue = [0, 0, 30, 3, 0, 0]'),
#  Text(0.0103359173126615, 0.25, 'x[1] <= 0.515\ngini = 0.117\nsamples = 32\nvalue = [0, 0, 30, 2, 0, 0]'),
#  Text(0.0068906115417743325, 0.19444444444444445, 'x[3] <= 1.95\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.0034453057708871662, 0.1388888888888889, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.0103359173126615, 0.1388888888888889, 'x[2] <= 0.21\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.0068906115417743325, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.013781223083548665, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.013781223083548665, 0.19444444444444445, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26, 0, 0, 0]'),
#  Text(0.017226528854435832, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.020671834625323, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04478897502153316, 0.3611111111111111, 'x[6] <= 79.0\ngini = 0.501\nsamples = 33\nvalue = [0, 1, 21, 10, 1, 0]'),
#  Text(0.041343669250646, 0.3055555555555556, 'x[2] <= 0.195\ngini = 0.453\nsamples = 30\nvalue = [0, 1, 21, 7, 1, 0]'),
#  Text(0.031007751937984496, 0.25, 'x[7] <= 0.996\ngini = 0.639\nsamples = 12\nvalue = [0, 1, 5, 5, 1, 0]'),
#  Text(0.020671834625323, 0.19444444444444445, 'x[9] <= 0.475\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.017226528854435832, 0.1388888888888889, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.024117140396210164, 0.1388888888888889, 'x[2] <= 0.03\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.020671834625323, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.02756244616709733, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.041343669250646, 0.19444444444444445, 'x[6] <= 22.5\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 0, 4, 1, 0]'),
#  Text(0.03789836347975883, 0.1388888888888889, 'x[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.034453057708871665, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.041343669250646, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.04478897502153316, 0.1388888888888889, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.05167958656330749, 0.25, 'x[1] <= 0.767\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 16, 2, 0, 0]'),
#  Text(0.04823428079242033, 0.19444444444444445, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(0.05512489233419466, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.04823428079242033, 0.3055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.05512489233419466, 0.4166666666666667, 'x[3] <= 1.95\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1, 0, 0, 0]'),
#  Text(0.05167958656330749, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.05857019810508183, 0.3611111111111111, 'x[6] <= 29.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.05512489233419466, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06201550387596899, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.053402239448751075, 0.5277777777777778, 'x[10] <= 9.7\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1, 0, 0]'),
#  Text(0.04995693367786391, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.056847545219638244, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07493540051679587, 0.5833333333333334, 'x[8] <= 3.255\ngini = 0.251\nsamples = 93\nvalue = [1, 5, 80, 7, 0, 0]'),
#  Text(0.0714900947459087, 0.5277777777777778, 'gini = 0.0\nsamples = 42\nvalue = [0, 0, 42, 0, 0, 0]'),
#  Text(0.07838070628768304, 0.5277777777777778, 'x[1] <= 0.53\ngini = 0.416\nsamples = 51\nvalue = [1, 5, 38, 7, 0, 0]'),
#  Text(0.06546080964685616, 0.4722222222222222, 'x[4] <= 0.089\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(0.06201550387596899, 0.4166666666666667, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(0.06890611541774333, 0.4166666666666667, 'x[5] <= 13.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.06546080964685616, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.07235142118863049, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0913006029285099, 0.4722222222222222, 'x[0] <= 8.95\ngini = 0.549\nsamples = 32\nvalue = [1, 5, 20, 6, 0, 0]'),
#  Text(0.08785529715762273, 0.4166666666666667, 'x[1] <= 0.647\ngini = 0.509\nsamples = 30\nvalue = [1, 5, 20, 4, 0, 0]'),
#  Text(0.07924203273040482, 0.3611111111111111, 'x[8] <= 3.365\ngini = 0.593\nsamples = 9\nvalue = [0, 1, 4, 4, 0, 0]'),
#  Text(0.07579672695951765, 0.3055555555555556, 'x[5] <= 12.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0, 0, 0]'),
#  Text(0.07235142118863049, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.07924203273040482, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.082687338501292, 0.3055555555555556, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.09646856158484066, 0.3611111111111111, 'x[10] <= 9.55\ngini = 0.381\nsamples = 21\nvalue = [1, 4, 16, 0, 0, 0]'),
#  Text(0.08957795004306632, 0.3055555555555556, 'x[10] <= 9.25\ngini = 0.133\nsamples = 14\nvalue = [0, 1, 13, 0, 0, 0]'),
#  Text(0.08613264427217916, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.09302325581395349, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.10335917312661498, 0.3055555555555556, 'x[1] <= 0.745\ngini = 0.612\nsamples = 7\nvalue = [1, 3, 3, 0, 0, 0]'),
#  Text(0.09991386735572783, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.10680447889750215, 0.25, 'x[9] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0, 0, 0]'),
#  Text(0.10335917312661498, 0.19444444444444445, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.11024978466838932, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.09474590869939707, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.11369509043927649, 0.6388888888888888, 'x[9] <= 0.485\ngini = 0.521\nsamples = 59\nvalue = [1, 1, 35, 21, 1, 0]'),
#  Text(0.10335917312661498, 0.5833333333333334, 'x[3] <= 1.3\ngini = 0.227\nsamples = 16\nvalue = [0, 0, 14, 1, 1, 0]'),
#  Text(0.09991386735572783, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.10680447889750215, 0.5277777777777778, 'x[7] <= 0.998\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(0.10335917312661498, 0.4722222222222222, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(0.11024978466838932, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.12403100775193798, 0.5833333333333334, 'x[0] <= 6.95\ngini = 0.544\nsamples = 43\nvalue = [1, 1, 21, 20, 0, 0]'),
#  Text(0.12058570198105081, 0.5277777777777778, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.12747631352282515, 0.5277777777777778, 'x[4] <= 0.082\ngini = 0.544\nsamples = 38\nvalue = [1, 1, 16, 20, 0, 0]'),
#  Text(0.11714039621016366, 0.4722222222222222, 'x[7] <= 0.996\ngini = 0.525\nsamples = 25\nvalue = [1, 0, 14, 10, 0, 0]'),
#  Text(0.11369509043927649, 0.4166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.12058570198105081, 0.4166666666666667, 'x[8] <= 3.07\ngini = 0.543\nsamples = 19\nvalue = [1, 0, 8, 10, 0, 0]'),
#  Text(0.11714039621016366, 0.3611111111111111, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.12403100775193798, 0.3611111111111111, 'x[5] <= 3.5\ngini = 0.508\nsamples = 16\nvalue = [1, 0, 5, 10, 0, 0]'),
#  Text(0.12058570198105081, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.12747631352282515, 0.3055555555555556, 'x[3] <= 2.55\ngini = 0.444\nsamples = 15\nvalue = [0, 0, 5, 10, 0, 0]'),
#  Text(0.12058570198105081, 0.25, 'x[5] <= 23.0\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 2, 8, 0, 0]'),
#  Text(0.11714039621016366, 0.19444444444444445, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.12403100775193798, 0.19444444444444445, 'x[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.12058570198105081, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.12747631352282515, 0.1388888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1343669250645995, 0.25, 'x[2] <= 0.295\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.13092161929371232, 0.19444444444444445, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.13781223083548666, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.13781223083548666, 0.4722222222222222, 'x[2] <= 0.305\ngini = 0.379\nsamples = 13\nvalue = [0, 1, 2, 10, 0, 0]'),
#  Text(0.1343669250645995, 0.4166666666666667, 'x[6] <= 16.0\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 0, 10, 0, 0]'),
#  Text(0.13092161929371232, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.13781223083548666, 0.3611111111111111, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.14125753660637383, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.09657622739018087, 0.75, 'x[4] <= 0.083\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 3, 8, 0, 0]'),
#  Text(0.09313092161929372, 0.6944444444444444, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.10002153316106804, 0.6944444444444444, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.33017065030146425, 0.8055555555555556, 'x[1] <= 0.555\ngini = 0.586\nsamples = 323\nvalue = [3, 5, 153, 139, 21, 2]'),
#  Text(0.2737133936261843, 0.75, 'x[4] <= 0.098\ngini = 0.59\nsamples = 176\nvalue = [1, 1, 61, 93, 18, 2]'),
#  Text(0.22529069767441862, 0.6944444444444444, 'x[9] <= 0.645\ngini = 0.566\nsamples = 137\nvalue = [0, 0, 38, 80, 17, 2]'),
#  Text(0.1726959517657192, 0.6388888888888888, 'x[3] <= 1.95\ngini = 0.548\nsamples = 56\nvalue = [0, 0, 28, 25, 3, 0]'),
#  Text(0.15848406546080965, 0.5833333333333334, 'x[8] <= 3.405\ngini = 0.461\nsamples = 16\nvalue = [0, 0, 4, 11, 1, 0]'),
#  Text(0.15503875968992248, 0.5277777777777778, 'x[1] <= 0.525\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 4, 5, 1, 0]'),
#  Text(0.1515934539190353, 0.4722222222222222, 'x[2] <= 0.2\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 4, 1, 1, 0]'),
#  Text(0.14814814814814814, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.15503875968992248, 0.4166666666666667, 'x[6] <= 10.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.1515934539190353, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15848406546080965, 0.3611111111111111, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.15848406546080965, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.16192937123169682, 0.5277777777777778, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.18690783807062877, 0.5833333333333334, 'x[5] <= 14.0\ngini = 0.515\nsamples = 40\nvalue = [0, 0, 24, 14, 2, 0]'),
#  Text(0.16881998277347116, 0.5277777777777778, 'x[5] <= 5.5\ngini = 0.571\nsamples = 14\nvalue = [0, 0, 4, 8, 2, 0]'),
#  Text(0.165374677002584, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.17226528854435832, 0.4722222222222222, 'x[10] <= 9.45\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(0.16881998277347116, 0.4166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.17571059431524547, 0.4166666666666667, 'x[7] <= 0.998\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.17226528854435832, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.17915590008613264, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.2049956933677864, 0.5277777777777778, 'x[6] <= 82.0\ngini = 0.355\nsamples = 26\nvalue = [0, 0, 20, 6, 0, 0]'),
#  Text(0.19638242894056848, 0.4722222222222222, 'x[1] <= 0.545\ngini = 0.287\nsamples = 23\nvalue = [0, 0, 19, 4, 0, 0]'),
#  Text(0.18949181739879414, 0.4166666666666667, 'x[3] <= 6.7\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]'),
#  Text(0.18604651162790697, 0.3611111111111111, 'x[4] <= 0.084\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(0.1826012058570198, 0.3055555555555556, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(0.18949181739879414, 0.3055555555555556, 'x[6] <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.18604651162790697, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1929371231696813, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1929371231696813, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20327304048234282, 0.4166666666666667, 'x[6] <= 50.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.19982773471145565, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.20671834625322996, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2136089577950043, 0.4722222222222222, 'x[10] <= 9.65\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.21016365202411713, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.21705426356589147, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.277885443583118, 0.6388888888888888, 'x[4] <= 0.094\ngini = 0.493\nsamples = 81\nvalue = [0, 0, 10, 55, 14, 2]'),
#  Text(0.266365202411714, 0.5833333333333334, 'x[3] <= 2.35\ngini = 0.459\nsamples = 76\nvalue = [0, 0, 9, 54, 11, 2]'),
#  Text(0.25366063738156763, 0.5277777777777778, 'x[0] <= 11.7\ngini = 0.555\nsamples = 55\nvalue = [0, 0, 8, 34, 11, 2]'),
#  Text(0.23858742463393626, 0.4722222222222222, 'x[6] <= 48.5\ngini = 0.468\nsamples = 47\nvalue = [0, 0, 6, 33, 7, 1]'),
#  Text(0.22566752799310938, 0.4166666666666667, 'x[7] <= 0.997\ngini = 0.359\nsamples = 38\nvalue = [0, 0, 3, 30, 4, 1]'),
#  Text(0.2136089577950043, 0.3611111111111111, 'x[5] <= 15.5\ngini = 0.542\nsamples = 12\nvalue = [0, 0, 0, 7, 4, 1]'),
#  Text(0.21016365202411713, 0.3055555555555556, 'x[2] <= 0.305\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 0, 2, 4, 1]'),
#  Text(0.20671834625322996, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.2136089577950043, 0.25, 'x[5] <= 10.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1]'),
#  Text(0.21016365202411713, 0.19444444444444445, 'x[8] <= 3.225\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.20671834625322996, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2136089577950043, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.21705426356589147, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.21705426356589147, 0.3055555555555556, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.23772609819121446, 0.3611111111111111, 'x[7] <= 0.999\ngini = 0.204\nsamples = 26\nvalue = [0, 0, 3, 23, 0, 0]'),
#  Text(0.23428079242032732, 0.3055555555555556, 'x[3] <= 2.15\ngini = 0.147\nsamples = 25\nvalue = [0, 0, 2, 23, 0, 0]'),
#  Text(0.22739018087855298, 0.25, 'x[4] <= 0.087\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 1, 21, 0, 0]'),
#  Text(0.2239448751076658, 0.19444444444444445, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.23083548664944015, 0.19444444444444445, 'x[8] <= 3.175\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.22739018087855298, 0.1388888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.23428079242032732, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24117140396210163, 0.25, 'x[9] <= 0.66\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.23772609819121446, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2446167097329888, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.24117140396210163, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.25150732127476316, 0.4166666666666667, 'x[2] <= 0.29\ngini = 0.667\nsamples = 9\nvalue = [0, 0, 3, 3, 3, 0]'),
#  Text(0.24806201550387597, 0.3611111111111111, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2549526270456503, 0.3611111111111111, 'x[6] <= 55.5\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 3, 0]'),
#  Text(0.25150732127476316, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.25839793281653745, 0.3055555555555556, 'x[9] <= 0.88\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.2549526270456503, 0.25, 'x[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.25150732127476316, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25839793281653745, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.26184323858742464, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.268733850129199, 0.4722222222222222, 'x[1] <= 0.295\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 2, 1, 4, 1]'),
#  Text(0.2652885443583118, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.2721791559000861, 0.4166666666666667, 'x[2] <= 0.675\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 0, 1]'),
#  Text(0.268733850129199, 0.3611111111111111, 'x[0] <= 12.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2652885443583118, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2721791559000861, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2756244616709733, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.27906976744186046, 0.5277777777777778, 'x[9] <= 0.665\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 1, 20, 0, 0]'),
#  Text(0.2756244616709733, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.28251507321274766, 0.4722222222222222, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 20, 0, 0]'),
#  Text(0.28940568475452194, 0.5833333333333334, 'x[8] <= 3.205\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.2859603789836348, 0.5277777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.29285099052540914, 0.5277777777777778, 'x[1] <= 0.36\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.28940568475452194, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2962962962962963, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.32213608957795004, 0.6944444444444444, 'x[5] <= 6.5\ngini = 0.539\nsamples = 39\nvalue = [1, 1, 23, 13, 1, 0]'),
#  Text(0.31352282515073215, 0.6388888888888888, 'x[5] <= 5.5\ngini = 0.521\nsamples = 13\nvalue = [0, 0, 4, 8, 1, 0]'),
#  Text(0.31007751937984496, 0.5833333333333334, 'x[6] <= 21.0\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 4, 3, 1, 0]'),
#  Text(0.3066322136089578, 0.5277777777777778, 'x[9] <= 1.065\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 0, 1, 0]'),
#  Text(0.3031869078380706, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.31007751937984496, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.31352282515073215, 0.5277777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3169681309216193, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.330749354005168, 0.6388888888888888, 'x[5] <= 30.0\ngini = 0.426\nsamples = 26\nvalue = [1, 1, 19, 5, 0, 0]'),
#  Text(0.32385874246339363, 0.5833333333333334, 'x[10] <= 9.25\ngini = 0.172\nsamples = 21\nvalue = [0, 0, 19, 2, 0, 0]'),
#  Text(0.32041343669250644, 0.5277777777777778, 'x[6] <= 59.0\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.3169681309216193, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.32385874246339363, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3273040482342808, 0.5277777777777778, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(0.3376399655469423, 0.5833333333333334, 'x[1] <= 0.49\ngini = 0.56\nsamples = 5\nvalue = [1, 1, 0, 3, 0, 0]'),
#  Text(0.3341946597760551, 0.5277777777777778, 'x[1] <= 0.455\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(0.330749354005168, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.3376399655469423, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.34108527131782945, 0.5277777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3866279069767442, 0.75, 'x[3] <= 1.95\ngini = 0.509\nsamples = 147\nvalue = [2, 4, 92, 46, 3, 0]'),
#  Text(0.36003445305770887, 0.6944444444444444, 'x[10] <= 9.85\ngini = 0.388\nsamples = 54\nvalue = [1, 2, 41, 10, 0, 0]'),
#  Text(0.3479758828596038, 0.6388888888888888, 'x[5] <= 3.5\ngini = 0.224\nsamples = 40\nvalue = [0, 1, 35, 4, 0, 0]'),
#  Text(0.34453057708871665, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.35142118863049093, 0.5833333333333334, 'x[3] <= 1.4\ngini = 0.148\nsamples = 38\nvalue = [0, 1, 35, 2, 0, 0]'),
#  Text(0.3479758828596038, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.35486649440137813, 0.5277777777777778, 'x[2] <= 0.595\ngini = 0.102\nsamples = 37\nvalue = [0, 0, 35, 2, 0, 0]'),
#  Text(0.35142118863049093, 0.4722222222222222, 'x[5] <= 26.5\ngini = 0.054\nsamples = 36\nvalue = [0, 0, 35, 1, 0, 0]'),
#  Text(0.3479758828596038, 0.4166666666666667, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32, 0, 0, 0]'),
#  Text(0.35486649440137813, 0.4166666666666667, 'x[10] <= 9.6\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.35142118863049093, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.35831180017226527, 0.3611111111111111, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.35831180017226527, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37209302325581395, 0.6388888888888888, 'x[1] <= 0.683\ngini = 0.622\nsamples = 14\nvalue = [1, 1, 6, 6, 0, 0]'),
#  Text(0.3652024117140396, 0.5833333333333334, 'x[9] <= 0.625\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 0, 6, 0, 0]'),
#  Text(0.36175710594315247, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3686477174849268, 0.5277777777777778, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.3789836347975883, 0.5833333333333334, 'x[0] <= 6.75\ngini = 0.245\nsamples = 7\nvalue = [1, 0, 6, 0, 0, 0]'),
#  Text(0.37553832902670115, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.38242894056847543, 0.5277777777777778, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.4132213608957795, 0.6944444444444444, 'x[6] <= 82.5\ngini = 0.548\nsamples = 93\nvalue = [1, 2, 51, 36, 3, 0]'),
#  Text(0.40977605512489235, 0.6388888888888888, 'x[0] <= 6.85\ngini = 0.564\nsamples = 84\nvalue = [1, 2, 42, 36, 3, 0]'),
#  Text(0.39276485788113696, 0.5833333333333334, 'x[6] <= 17.5\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 6, 0, 0, 0]'),
#  Text(0.38931955211024977, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3962101636520241, 0.5277777777777778, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.42678725236864773, 0.5833333333333334, 'x[7] <= 0.997\ngini = 0.561\nsamples = 77\nvalue = [1, 1, 36, 36, 3, 0]'),
#  Text(0.40310077519379844, 0.5277777777777778, 'x[1] <= 0.84\ngini = 0.446\nsamples = 11\nvalue = [0, 1, 1, 8, 1, 0]'),
#  Text(0.3962101636520241, 0.4722222222222222, 'x[4] <= 0.074\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.39276485788113696, 0.4166666666666667, 'x[3] <= 2.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.38931955211024977, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3962101636520241, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3996554694229113, 0.4166666666666667, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.4099913867355728, 0.4722222222222222, 'x[1] <= 0.945\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.40654608096468564, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4134366925064599, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.45047372954349696, 0.5277777777777778, 'x[2] <= 0.26\ngini = 0.538\nsamples = 66\nvalue = [1, 0, 35, 28, 2, 0]'),
#  Text(0.43238587424633934, 0.4722222222222222, 'x[8] <= 3.275\ngini = 0.486\nsamples = 50\nvalue = [0, 0, 31, 18, 1, 0]'),
#  Text(0.42032730404823426, 0.4166666666666667, 'x[1] <= 0.725\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 1, 0, 0]'),
#  Text(0.4168819982773471, 0.3611111111111111, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.42377260981912146, 0.3611111111111111, 'x[7] <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.42032730404823426, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4272179155900086, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4444444444444444, 0.4166666666666667, 'x[10] <= 9.55\ngini = 0.526\nsamples = 36\nvalue = [0, 0, 18, 17, 1, 0]'),
#  Text(0.43755383290267014, 0.3611111111111111, 'x[9] <= 0.645\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 3, 11, 0, 0]'),
#  Text(0.43410852713178294, 0.3055555555555556, 'x[4] <= 0.082\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.4306632213608958, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.43755383290267014, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4409991386735573, 0.3055555555555556, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.45133505598621876, 0.3611111111111111, 'x[8] <= 3.29\ngini = 0.459\nsamples = 22\nvalue = [0, 0, 15, 6, 1, 0]'),
#  Text(0.4478897502153316, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.45478036175710596, 0.3055555555555556, 'x[7] <= 0.997\ngini = 0.395\nsamples = 20\nvalue = [0, 0, 15, 4, 1, 0]'),
#  Text(0.45133505598621876, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4582256675279931, 0.25, 'x[2] <= 0.005\ngini = 0.332\nsamples = 19\nvalue = [0, 0, 15, 4, 0, 0]'),
#  Text(0.4496124031007752, 0.19444444444444445, 'x[0] <= 7.35\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.446167097329888, 0.1388888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.45305770887166236, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.46683893195521103, 0.19444444444444445, 'x[9] <= 0.625\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 14, 2, 0, 0]'),
#  Text(0.4599483204134367, 0.1388888888888889, 'x[6] <= 47.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.45650301464254955, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.46339362618432384, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4737295434969854, 0.1388888888888889, 'x[10] <= 9.75\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 1, 0, 0]'),
#  Text(0.4702842377260982, 0.08333333333333333, 'x[5] <= 9.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.46683893195521103, 0.027777777777777776, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4737295434969854, 0.027777777777777776, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4771748492678725, 0.08333333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.46856158484065463, 0.4722222222222222, 'x[4] <= 0.078\ngini = 0.539\nsamples = 16\nvalue = [1, 0, 4, 10, 1, 0]'),
#  Text(0.46511627906976744, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4720068906115418, 0.4166666666666667, 'x[4] <= 0.114\ngini = 0.391\nsamples = 13\nvalue = [1, 0, 1, 10, 1, 0]'),
#  Text(0.46511627906976744, 0.3611111111111111, 'x[7] <= 1.001\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.4616709732988803, 0.3055555555555556, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.46856158484065463, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4788975021533161, 0.3611111111111111, 'x[8] <= 3.075\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.4754521963824289, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.48234280792420325, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.4166666666666667, 0.6388888888888888, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.4453057708871662, 0.8611111111111112, 'x[8] <= 2.935\ngini = 0.178\nsamples = 82\nvalue = [0, 1, 74, 7, 0, 0]'),
#  Text(0.43669250645994834, 0.8055555555555556, 'x[10] <= 9.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.43324720068906114, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4401378122308355, 0.75, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.45391903531438416, 0.8055555555555556, 'x[3] <= 1.55\ngini = 0.121\nsamples = 78\nvalue = [0, 1, 73, 4, 0, 0]'),
#  Text(0.4470284237726098, 0.75, 'x[8] <= 3.24\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.4435831180017227, 0.6944444444444444, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.45047372954349696, 0.6944444444444444, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4608096468561585, 0.75, 'x[6] <= 109.5\ngini = 0.1\nsamples = 76\nvalue = [0, 0, 72, 4, 0, 0]'),
#  Text(0.4573643410852713, 0.6944444444444444, 'x[8] <= 3.175\ngini = 0.252\nsamples = 27\nvalue = [0, 0, 23, 4, 0, 0]'),
#  Text(0.45047372954349696, 0.6388888888888888, 'x[9] <= 0.54\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.4470284237726098, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.45391903531438416, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.46425495262704564, 0.6388888888888888, 'x[1] <= 0.545\ngini = 0.165\nsamples = 22\nvalue = [0, 0, 20, 2, 0, 0]'),
#  Text(0.4608096468561585, 0.5833333333333334, 'x[5] <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.4573643410852713, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.46425495262704564, 0.5277777777777778, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.46770025839793283, 0.5833333333333334, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(0.46425495262704564, 0.6944444444444444, 'gini = 0.0\nsamples = 49\nvalue = [0, 0, 49, 0, 0, 0]'),
#  Text(0.7754966085271318, 0.9166666666666666, 'x[10] <= 11.55\ngini = 0.647\nsamples = 533\nvalue = [2, 15, 106, 268, 130, 12]'),
#  Text(0.6285125968992248, 0.8611111111111112, 'x[1] <= 0.405\ngini = 0.629\nsamples = 356\nvalue = [2, 13, 96, 186, 55, 4]'),
#  Text(0.5529715762273901, 0.8055555555555556, 'x[9] <= 0.735\ngini = 0.653\nsamples = 118\nvalue = [0, 1, 20, 53, 40, 4]'),
#  Text(0.5068906115417743, 0.75, 'x[1] <= 0.287\ngini = 0.627\nsamples = 61\nvalue = [0, 1, 13, 33, 11, 3]'),
#  Text(0.48492678725236865, 0.6944444444444444, 'x[4] <= 0.075\ngini = 0.64\nsamples = 15\nvalue = [0, 0, 7, 4, 4, 0]'),
#  Text(0.4780361757105943, 0.6388888888888888, 'x[9] <= 0.68\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 1, 3, 4, 0]'),
#  Text(0.47459086993970717, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.48148148148148145, 0.5833333333333334, 'x[6] <= 22.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.4780361757105943, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.48492678725236865, 0.5277777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.491817398794143, 0.6388888888888888, 'x[7] <= 0.999\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.4883720930232558, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.49526270456503013, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.52885443583118, 0.6944444444444444, 'x[8] <= 3.285\ngini = 0.558\nsamples = 46\nvalue = [0, 1, 6, 29, 7, 3]'),
#  Text(0.5107665805340224, 0.6388888888888888, 'x[8] <= 3.145\ngini = 0.656\nsamples = 28\nvalue = [0, 0, 4, 14, 7, 3]'),
#  Text(0.5021533161068045, 0.5833333333333334, 'x[9] <= 0.715\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 1, 10, 1, 0]'),
#  Text(0.49870801033591733, 0.5277777777777778, 'x[4] <= 0.097\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.49526270456503013, 0.4722222222222222, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.5021533161068045, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5055986218776917, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5193798449612403, 0.5833333333333334, 'x[7] <= 0.995\ngini = 0.727\nsamples = 16\nvalue = [0, 0, 3, 4, 6, 3]'),
#  Text(0.512489233419466, 0.5277777777777778, 'x[5] <= 16.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]'),
#  Text(0.5090439276485789, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.5159345391903531, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5262704565030146, 0.5277777777777778, 'x[9] <= 0.66\ngini = 0.727\nsamples = 11\nvalue = [0, 0, 3, 4, 2, 2]'),
#  Text(0.5228251507321274, 0.4722222222222222, 'x[9] <= 0.605\ngini = 0.719\nsamples = 8\nvalue = [0, 0, 3, 1, 2, 2]'),
#  Text(0.5159345391903531, 0.4166666666666667, 'x[5] <= 8.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.512489233419466, 0.3611111111111111, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5193798449612403, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5297157622739018, 0.4166666666666667, 'x[8] <= 3.16\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 0, 2, 2]'),
#  Text(0.5262704565030146, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.533161068044789, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5297157622739018, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5469422911283376, 0.6388888888888888, 'x[6] <= 102.5\ngini = 0.29\nsamples = 18\nvalue = [0, 1, 2, 15, 0, 0]'),
#  Text(0.5434969853574505, 0.5833333333333334, 'x[10] <= 10.8\ngini = 0.208\nsamples = 17\nvalue = [0, 0, 2, 15, 0, 0]'),
#  Text(0.5400516795865633, 0.5277777777777778, 'x[7] <= 0.996\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.5366063738156761, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5434969853574505, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5469422911283376, 0.5277777777777778, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.5503875968992248, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5990525409130061, 0.75, 'x[6] <= 104.5\ngini = 0.603\nsamples = 57\nvalue = [0, 0, 7, 20, 29, 1]'),
#  Text(0.5956072351421189, 0.6944444444444444, 'x[7] <= 0.998\ngini = 0.569\nsamples = 54\nvalue = [0, 0, 4, 20, 29, 1]'),
#  Text(0.5822566752799311, 0.6388888888888888, 'x[8] <= 3.395\ngini = 0.623\nsamples = 33\nvalue = [0, 0, 4, 15, 13, 1]'),
#  Text(0.5658914728682171, 0.5833333333333334, 'x[4] <= 0.061\ngini = 0.58\nsamples = 24\nvalue = [0, 0, 3, 14, 6, 1]'),
#  Text(0.553832902670112, 0.5277777777777778, 'x[0] <= 8.5\ngini = 0.667\nsamples = 6\nvalue = [0, 0, 1, 1, 3, 1]'),
#  Text(0.5503875968992248, 0.4722222222222222, 'x[4] <= 0.05\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1]'),
#  Text(0.5469422911283376, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.553832902670112, 0.4166666666666667, 'x[4] <= 0.054\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.5503875968992248, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5572782084409992, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5572782084409992, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5779500430663221, 0.5277777777777778, 'x[2] <= 0.535\ngini = 0.438\nsamples = 18\nvalue = [0, 0, 2, 13, 3, 0]'),
#  Text(0.5710594315245479, 0.4722222222222222, 'x[6] <= 20.5\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 0, 12, 2, 0]'),
#  Text(0.5676141257536607, 0.4166666666666667, 'x[2] <= 0.425\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.5641688199827735, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5710594315245479, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5745047372954349, 0.4166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.5848406546080964, 0.4722222222222222, 'x[9] <= 0.785\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.5813953488372093, 0.4166666666666667, 'x[6] <= 66.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.5779500430663221, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5848406546080964, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5882859603789836, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5986218776916451, 0.5833333333333334, 'x[10] <= 10.75\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 1, 1, 7, 0]'),
#  Text(0.595176571920758, 0.5277777777777778, 'x[8] <= 3.475\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.5917312661498708, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5986218776916451, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6020671834625323, 0.5277777777777778, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.6089577950043066, 0.6388888888888888, 'x[10] <= 10.45\ngini = 0.363\nsamples = 21\nvalue = [0, 0, 0, 5, 16, 0]'),
#  Text(0.6055124892334195, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6124031007751938, 0.5833333333333334, 'x[9] <= 1.055\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 0, 3, 16, 0]'),
#  Text(0.6089577950043066, 0.5277777777777778, 'x[7] <= 1.0\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 0, 2, 16, 0]'),
#  Text(0.6055124892334195, 0.4722222222222222, 'x[6] <= 21.5\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 0, 1, 16, 0]'),
#  Text(0.6020671834625323, 0.4166666666666667, 'x[7] <= 0.998\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.5986218776916451, 0.3611111111111111, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.6055124892334195, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6089577950043066, 0.4166666666666667, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(0.6124031007751938, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.615848406546081, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6024978466838932, 0.6944444444444444, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7040536175710594, 0.8055555555555556, 'x[9] <= 0.525\ngini = 0.579\nsamples = 238\nvalue = [2, 12, 76, 133, 15, 0]'),
#  Text(0.6451335055986219, 0.75, 'x[0] <= 6.85\ngini = 0.547\nsamples = 31\nvalue = [1, 3, 19, 8, 0, 0]'),
#  Text(0.6365202411714039, 0.6944444444444444, 'x[4] <= 0.141\ngini = 0.66\nsamples = 10\nvalue = [0, 3, 3, 4, 0, 0]'),
#  Text(0.6330749354005168, 0.6388888888888888, 'x[9] <= 0.455\ngini = 0.594\nsamples = 8\nvalue = [0, 3, 1, 4, 0, 0]'),
#  Text(0.6261843238587425, 0.5833333333333334, 'x[5] <= 15.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.6227390180878553, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6296296296296297, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6399655469422911, 0.5833333333333334, 'x[9] <= 0.495\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 0, 4, 0, 0]'),
#  Text(0.6365202411714039, 0.5277777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6434108527131783, 0.5277777777777778, 'x[3] <= 2.85\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(0.6399655469422911, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6468561584840654, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.6399655469422911, 0.6388888888888888, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6537467700258398, 0.6944444444444444, 'x[2] <= 0.295\ngini = 0.381\nsamples = 21\nvalue = [1, 0, 16, 4, 0, 0]'),
#  Text(0.6503014642549526, 0.6388888888888888, 'x[10] <= 10.45\ngini = 0.277\nsamples = 19\nvalue = [1, 0, 16, 2, 0, 0]'),
#  Text(0.6468561584840654, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6537467700258398, 0.5833333333333334, 'x[8] <= 3.47\ngini = 0.204\nsamples = 18\nvalue = [1, 0, 16, 1, 0, 0]'),
#  Text(0.6503014642549526, 0.5277777777777778, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(0.657192075796727, 0.5277777777777778, 'x[2] <= 0.01\ngini = 0.625\nsamples = 4\nvalue = [1, 0, 2, 1, 0, 0]'),
#  Text(0.6537467700258398, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6606373815676141, 0.4722222222222222, 'x[8] <= 3.495\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0]'),
#  Text(0.657192075796727, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.6640826873385013, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.657192075796727, 0.6388888888888888, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.762973729543497, 0.75, 'x[5] <= 12.5\ngini = 0.552\nsamples = 207\nvalue = [1, 9, 57, 125, 15, 0]'),
#  Text(0.7344961240310077, 0.6944444444444444, 'x[4] <= 0.09\ngini = 0.65\nsamples = 90\nvalue = [1, 8, 32, 41, 8, 0]'),
#  Text(0.7153316106804479, 0.6388888888888888, 'x[8] <= 3.6\ngini = 0.591\nsamples = 66\nvalue = [0, 6, 19, 37, 4, 0]'),
#  Text(0.7118863049095607, 0.5833333333333334, 'x[6] <= 61.0\ngini = 0.572\nsamples = 62\nvalue = [0, 6, 15, 37, 4, 0]'),
#  Text(0.6976744186046512, 0.5277777777777778, 'x[9] <= 0.615\ngini = 0.548\nsamples = 57\nvalue = [0, 6, 11, 36, 4, 0]'),
#  Text(0.6795865633074936, 0.4722222222222222, 'x[4] <= 0.079\ngini = 0.699\nsamples = 23\nvalue = [0, 5, 7, 9, 2, 0]'),
#  Text(0.6709732988802756, 0.4166666666666667, 'x[10] <= 11.1\ngini = 0.667\nsamples = 15\nvalue = [0, 4, 7, 3, 1, 0]'),
#  Text(0.6640826873385013, 0.3611111111111111, 'x[4] <= 0.076\ngini = 0.691\nsamples = 9\nvalue = [0, 4, 2, 2, 1, 0]'),
#  Text(0.6606373815676141, 0.3055555555555556, 'x[5] <= 6.5\ngini = 0.571\nsamples = 7\nvalue = [0, 4, 0, 2, 1, 0]'),
#  Text(0.657192075796727, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.6640826873385013, 0.25, 'x[4] <= 0.068\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 0, 2, 1, 0]'),
#  Text(0.6606373815676141, 0.19444444444444445, 'x[5] <= 9.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.657192075796727, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6640826873385013, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6675279931093885, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
# ...
#  Text(0.7536606373815676, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7571059431524548, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.7914513350559862, 0.6944444444444444, 'x[3] <= 4.4\ngini = 0.435\nsamples = 117\nvalue = [0, 1, 25, 84, 7, 0]'),
#  Text(0.77885443583118, 0.6388888888888888, 'x[4] <= 0.056\ngini = 0.404\nsamples = 111\nvalue = [0, 1, 20, 83, 7, 0]'),
#  Text(0.7639965546942291, 0.5833333333333334, 'x[6] <= 83.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.7605512489233419, 0.5277777777777778, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.7674418604651163, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7937123169681309, 0.5833333333333334, 'x[7] <= 0.996\ngini = 0.374\nsamples = 106\nvalue = [0, 1, 16, 82, 7, 0]'),
#  Text(0.7743324720068906, 0.5277777777777778, 'x[1] <= 0.425\ngini = 0.188\nsamples = 58\nvalue = [0, 0, 5, 52, 1, 0]'),
#  Text(0.7657192075796727, 0.4722222222222222, 'x[2] <= 0.285\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.7622739018087855, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7691645133505599, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7829457364341085, 0.4722222222222222, 'x[9] <= 0.535\ngini = 0.139\nsamples = 54\nvalue = [0, 0, 3, 50, 1, 0]'),
#  Text(0.7760551248923342, 0.4166666666666667, 'x[2] <= 0.005\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.772609819121447, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7795004306632214, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7898363479758829, 0.4166666666666667, 'x[10] <= 10.575\ngini = 0.11\nsamples = 52\nvalue = [0, 0, 2, 49, 1, 0]'),
#  Text(0.7863910422049957, 0.3611111111111111, 'x[7] <= 0.995\ngini = 0.357\nsamples = 14\nvalue = [0, 0, 2, 11, 1, 0]'),
#  Text(0.7829457364341085, 0.3055555555555556, 'x[5] <= 23.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.7795004306632214, 0.25, 'x[10] <= 10.525\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7760551248923342, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7829457364341085, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7863910422049957, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7898363479758829, 0.3055555555555556, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.7932816537467701, 0.3611111111111111, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 38, 0, 0]'),
#  Text(0.8130921619293713, 0.5277777777777778, 'x[3] <= 1.95\ngini = 0.541\nsamples = 48\nvalue = [0, 1, 11, 30, 6, 0]'),
#  Text(0.8001722652885443, 0.4722222222222222, 'x[3] <= 1.6\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.7967269595176572, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8036175710594315, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8260120585701981, 0.4722222222222222, 'x[8] <= 3.335\ngini = 0.489\nsamples = 44\nvalue = [0, 1, 8, 30, 5, 0]'),
#  Text(0.8105081826012058, 0.4166666666666667, 'x[4] <= 0.097\ngini = 0.35\nsamples = 31\nvalue = [0, 0, 7, 24, 0, 0]'),
#  Text(0.8001722652885443, 0.3611111111111111, 'x[4] <= 0.062\ngini = 0.227\nsamples = 23\nvalue = [0, 0, 3, 20, 0, 0]'),
#  Text(0.7967269595176572, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8036175710594315, 0.3055555555555556, 'x[1] <= 0.415\ngini = 0.165\nsamples = 22\nvalue = [0, 0, 2, 20, 0, 0]'),
#  Text(0.8001722652885443, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8070628768303187, 0.25, 'x[0] <= 8.1\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 1, 20, 0, 0]'),
#  Text(0.8036175710594315, 0.19444444444444445, 'x[10] <= 10.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8001722652885443, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8070628768303187, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8105081826012058, 0.19444444444444445, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.8208440999138673, 0.3611111111111111, 'x[9] <= 0.715\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.8173987941429802, 0.3055555555555556, 'x[2] <= 0.1\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.813953488372093, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8208440999138673, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.8242894056847545, 0.3055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8415159345391904, 0.4166666666666667, 'x[9] <= 0.68\ngini = 0.627\nsamples = 13\nvalue = [0, 1, 1, 6, 5, 0]'),
#  Text(0.834625322997416, 0.3611111111111111, 'x[6] <= 75.5\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 5, 0, 0]'),
#  Text(0.8311800172265289, 0.3055555555555556, 'x[1] <= 0.947\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.8277347114556417, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.834625322997416, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8380706287683032, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8484065460809647, 0.3611111111111111, 'x[7] <= 0.999\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(0.8449612403100775, 0.3055555555555556, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.8518518518518519, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8040482342807924, 0.6388888888888888, 'x[6] <= 138.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.8006029285099052, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.8074935400516796, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9224806201550387, 0.8611111111111112, 'x[9] <= 0.685\ngini = 0.6\nsamples = 177\nvalue = [0, 2, 10, 82, 75, 8]'),
#  Text(0.8828596037898363, 0.8055555555555556, 'x[6] <= 15.5\ngini = 0.537\nsamples = 95\nvalue = [0, 2, 8, 59, 25, 1]'),
#  Text(0.8656330749354005, 0.75, 'x[9] <= 0.585\ngini = 0.531\nsamples = 25\nvalue = [0, 0, 2, 8, 15, 0]'),
#  Text(0.8587424633936261, 0.6944444444444444, 'x[7] <= 0.994\ngini = 0.56\nsamples = 10\nvalue = [0, 0, 2, 6, 2, 0]'),
#  Text(0.8552971576227391, 0.6388888888888888, 'x[7] <= 0.992\ngini = 0.667\nsamples = 6\nvalue = [0, 0, 2, 2, 2, 0]'),
#  Text(0.8518518518518519, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8587424633936261, 0.5833333333333334, 'x[2] <= 0.2\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.8552971576227391, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8621877691645133, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8621877691645133, 0.6388888888888888, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8725236864771748, 0.6944444444444444, 'x[6] <= 9.0\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 0, 2, 13, 0]'),
#  Text(0.8690783807062877, 0.6388888888888888, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.875968992248062, 0.6388888888888888, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(0.9000861326442722, 0.75, 'x[5] <= 31.5\ngini = 0.44\nsamples = 70\nvalue = [0, 2, 6, 51, 10, 1]'),
#  Text(0.8897502153316107, 0.6944444444444444, 'x[0] <= 4.65\ngini = 0.381\nsamples = 62\nvalue = [0, 2, 6, 48, 6, 0]'),
#  Text(0.8863049095607235, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8931955211024979, 0.6388888888888888, 'x[2] <= 0.725\ngini = 0.361\nsamples = 61\nvalue = [0, 1, 6, 48, 6, 0]'),
#  Text(0.8897502153316107, 0.5833333333333334, 'x[6] <= 26.5\ngini = 0.343\nsamples = 60\nvalue = [0, 1, 6, 48, 5, 0]'),
#  Text(0.8690783807062877, 0.5277777777777778, 'x[0] <= 7.0\ngini = 0.518\nsamples = 23\nvalue = [0, 1, 5, 15, 2, 0]'),
#  Text(0.8621877691645133, 0.4722222222222222, 'x[2] <= 0.025\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 4, 1, 0, 0]'),
#  Text(0.8587424633936261, 0.4166666666666667, 'x[9] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.8552971576227391, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8621877691645133, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8656330749354005, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.875968992248062, 0.4722222222222222, 'x[3] <= 2.475\ngini = 0.304\nsamples = 17\nvalue = [0, 0, 1, 14, 2, 0]'),
#  Text(0.8725236864771748, 0.4166666666666667, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.8794142980189492, 0.4166666666666667, 'x[7] <= 0.997\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 1, 2, 2, 0]'),
#  Text(0.875968992248062, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8828596037898363, 0.3611111111111111, 'x[8] <= 3.125\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.8794142980189492, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8863049095607235, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9104220499569337, 0.5277777777777778, 'x[6] <= 89.5\ngini = 0.197\nsamples = 37\nvalue = [0, 0, 1, 33, 3, 0]'),
#  Text(0.9035314384151594, 0.4722222222222222, 'x[6] <= 35.5\ngini = 0.111\nsamples = 34\nvalue = [0, 0, 0, 32, 2, 0]'),
#  Text(0.9000861326442722, 0.4166666666666667, 'x[5] <= 23.5\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 0, 11, 2, 0]'),
#  Text(0.896640826873385, 0.3611111111111111, 'x[10] <= 11.75\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 11, 1, 0]'),
#  Text(0.8931955211024979, 0.3055555555555556, 'x[8] <= 3.38\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8897502153316107, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.896640826873385, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9000861326442722, 0.3055555555555556, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.9035314384151594, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9069767441860465, 0.4166666666666667, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 21, 0, 0]'),
#  Text(0.917312661498708, 0.4722222222222222, 'x[3] <= 1.95\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0]'),
#  Text(0.9138673557278209, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9207579672695951, 0.4166666666666667, 'x[2] <= 0.13\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.917312661498708, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9242032730404823, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.896640826873385, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9104220499569337, 0.6944444444444444, 'x[3] <= 2.1\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 0, 3, 4, 1]'),
#  Text(0.9069767441860465, 0.6388888888888888, 'x[9] <= 0.61\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1]'),
#  Text(0.9035314384151594, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9104220499569337, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9138673557278209, 0.6388888888888888, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.9621016365202412, 0.8055555555555556, 'x[5] <= 18.5\ngini = 0.542\nsamples = 82\nvalue = [0, 0, 2, 23, 50, 7]'),
#  Text(0.9397071490094746, 0.75, 'x[5] <= 9.5\ngini = 0.465\nsamples = 57\nvalue = [0, 0, 1, 10, 40, 6]'),
#  Text(0.9276485788113695, 0.6944444444444444, 'x[7] <= 0.995\ngini = 0.623\nsamples = 27\nvalue = [0, 0, 0, 9, 13, 5]'),
#  Text(0.9207579672695951, 0.6388888888888888, 'x[10] <= 12.95\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 0, 8, 1]'),
#  Text(0.917312661498708, 0.5833333333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.9242032730404823, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9345391903531438, 0.6388888888888888, 'x[9] <= 0.695\ngini = 0.623\nsamples = 18\nvalue = [0, 0, 0, 9, 5, 4]'),
#  Text(0.9310938845822567, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.937984496124031, 0.5833333333333334, 'x[3] <= 2.625\ngini = 0.524\nsamples = 15\nvalue = [0, 0, 0, 9, 5, 1]'),
#  Text(0.9345391903531438, 0.5277777777777778, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9414298018949182, 0.5277777777777778, 'x[9] <= 0.925\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 0, 4, 5, 1]'),
#  Text(0.937984496124031, 0.4722222222222222, 'x[0] <= 12.2\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 0, 1, 5, 1]'),
#  Text(0.9345391903531438, 0.4166666666666667, 'x[4] <= 0.082\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 0, 5, 1]'),
#  Text(0.9310938845822567, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.937984496124031, 0.3611111111111111, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9414298018949182, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9448751076658053, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9517657192075797, 0.6944444444444444, 'x[9] <= 0.695\ngini = 0.187\nsamples = 30\nvalue = [0, 0, 1, 1, 27, 1]'),
#  Text(0.9483204134366925, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9552110249784669, 0.6388888888888888, 'x[5] <= 14.5\ngini = 0.131\nsamples = 29\nvalue = [0, 0, 0, 1, 27, 1]'),
#  Text(0.9517657192075797, 0.5833333333333334, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 22, 0]'),
#  Text(0.958656330749354, 0.5833333333333334, 'x[5] <= 15.5\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 0, 1, 5, 1]'),
#  Text(0.9552110249784669, 0.5277777777777778, 'x[1] <= 0.265\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.9517657192075797, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.958656330749354, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9621016365202412, 0.5277777777777778, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9844961240310077, 0.75, 'x[8] <= 3.36\ngini = 0.566\nsamples = 25\nvalue = [0, 0, 1, 13, 10, 1]'),
#  Text(0.9758828596037898, 0.6944444444444444, 'x[7] <= 0.995\ngini = 0.439\nsamples = 14\nvalue = [0, 0, 1, 3, 10, 0]'),
#  Text(0.9689922480620154, 0.6388888888888888, 'x[4] <= 0.069\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(0.9655469422911284, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9724375538329026, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9827734711455641, 0.6388888888888888, 'x[10] <= 13.75\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 0, 8, 0]'),
#  Text(0.979328165374677, 0.5833333333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.9862187769164513, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9931093884582257, 0.6944444444444444, 'x[8] <= 3.7\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 0, 1]'),
#  Text(0.9896640826873385, 0.6388888888888888, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.9965546942291128, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]')]

# %%
df1 = df.head(30)

# %%
x1 = df1.drop(columns="quality")

# %%
y1 = df1.quality

# %%
dt_model1 = DecisionTreeClassifier()

# %%
dt_model1.fit(x1,y1)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True)
# Out:
# [Text(0.625, 0.9166666666666666, 'x[2] <= 0.42\ngini = 0.471\nsamples = 30\nvalue = [1, 21, 5, 3]'),
#  Text(0.4166666666666667, 0.75, 'x[6] <= 22.0\ngini = 0.334\nsamples = 26\nvalue = [1, 21, 2, 2]'),
#  Text(0.25, 0.5833333333333334, 'x[5] <= 8.5\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2]'),
#  Text(0.16666666666666666, 0.4166666666666667, 'x[6] <= 13.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]'),
#  Text(0.08333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.5833333333333334, 0.5833333333333334, 'x[10] <= 9.05\ngini = 0.169\nsamples = 22\nvalue = [1, 20, 1, 0]'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[1] <= 0.415\ngini = 0.091\nsamples = 21\nvalue = [0, 20, 1, 0]'),
#  Text(0.5833333333333334, 0.25, 'x[2] <= 0.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 18\nvalue = [0, 18, 0, 0]'),
#  Text(0.8333333333333334, 0.75, 'x[6] <= 81.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1]'),
#  Text(0.75, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(0.9166666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]')]

# %% [markdown]
# ## Inferences:
# - Samples in the box1 mean no of datapoints we have considered.
# - Values in box1 mean that we had 4 classes i.e. 4,5,6,7 in quality column (output column) so values = [1,21,5,3] means we have:
#     - 1 value of class 4
#     - 21 values of class 5
#     - 5 values of class 6
#     - 3 values of class 7
#
#
#     <br>Total of all values will result in total sample values i.e. 1 + 21 + 5 + 3 = 30
#
# - x[1] here means the column which is the parent node i.e. 2nd column of x dataframe which shows it has the lowest gini impurity
#
#     - Based on x[2] = 0.335 (threshold) of x[2] column values if greater than it will got right side else left
# - 26 samples in right side split shows 26 values greater than x[2]'s 0.335.
# - Now in left hand node the same thing is repeated started from again calculating gini.

# %%
# Plot with column and class names

plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True,class_names = [str(i)for i in set(y1)], feature_names = x1.columns)
# Out:
# [Text(0.625, 0.9166666666666666, 'citric acid <= 0.42\ngini = 0.471\nsamples = 30\nvalue = [1, 21, 5, 3]\nclass = 5'),
#  Text(0.4166666666666667, 0.75, 'total sulfur dioxide <= 22.0\ngini = 0.334\nsamples = 26\nvalue = [1, 21, 2, 2]\nclass = 5'),
#  Text(0.25, 0.5833333333333334, 'free sulfur dioxide <= 8.5\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2]\nclass = 7'),
#  Text(0.16666666666666666, 0.4166666666666667, 'total sulfur dioxide <= 13.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = 5'),
#  Text(0.08333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = 5'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = 6'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = 7'),
#  Text(0.5833333333333334, 0.5833333333333334, 'alcohol <= 9.05\ngini = 0.169\nsamples = 22\nvalue = [1, 20, 1, 0]\nclass = 5'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = 4'),
#  Text(0.6666666666666666, 0.4166666666666667, 'volatile acidity <= 0.415\ngini = 0.091\nsamples = 21\nvalue = [0, 20, 1, 0]\nclass = 5'),
#  Text(0.5833333333333334, 0.25, 'citric acid <= 0.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0]\nclass = 5'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = 6'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = 5'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 18\nvalue = [0, 18, 0, 0]\nclass = 5'),
#  Text(0.8333333333333334, 0.75, 'total sulfur dioxide <= 81.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1]\nclass = 6'),
#  Text(0.75, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = 6'),
#  Text(0.9166666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = 7')]

# %% [markdown]
# - Performing Post Prunning on level 3 where there are 20 records for class 5 and 1 record for class 6.
#     - Removing level 3 to control complexity of the tree

# %%
# Checking train and test accuracy
dt_model1.predict(x1)
# Out:
# array([5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5,
#        5, 5, 6, 5, 5, 5, 5, 6], dtype=int64)

# %%
dt_model1.score(x1,y1)
# Out:
# 1.0

# %%
dt_model1.score(x_test,y_test)
# Out:
# 0.475

# %% [markdown]
# Here the model is overfitted as we are getting higher accuracy and on random sample as input its giving lower accuracy.
#
# - Here lower accuracy isnt a great issue as compared to overfitting so we would resolve overfitting here.
